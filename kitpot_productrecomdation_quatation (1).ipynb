# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Your dataset
products = [

  {
    "_id": "62da57fa863ba7c37a1315cf",
    "title": "Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Frosty Grey)",
    "description": "Product Name: Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Frosty Grey) Description: Introducing the Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan, featuring an elegant frosty grey finish. This fan is designed to keep you cool while also maintaining a clean home environment with its unique Goodbye Dust technology. Its 1200mm sweep size ensures powerful air delivery for effective cooling in large rooms up to 180 sq ft. Key Features: * Frosty Grey Finish: Adds a modern touch to your decor while complementing various color schemes. * Goodbye Dust Technology: Specially treated blades repel dust accumulation, making cleaning easier and less frequent. * Powerful Air Delivery: With a 1200mm sweep size, enjoy efficient cooling even in larger spaces. * High-Performance Motor: Ensures smooth operation and long lifespan, delivering reliable performance year after year. * Ribbed Aluminium Blades: Designed for optimal balance between style and functionality. * Energy Efficient: Consumes low power without compromising on performance or durability. * Easy Installation: Compatible with standard ceiling mounts, allowing easy installation for DIY enthusiasts. * Wide Range of Speeds: Offers multiple speed settings, enabling customized comfort based on personal preferences. This Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan combines sleek design, innovative features, and dependable performance. Experience enhanced air circulation and improved indoor air quality today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315da",
    "title": "Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold)",
    "description": "Product Name: Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold) Description: * Introducing the Usha Bellissa 1200mm Goodbye Dust Ceiling Fan, featuring an innovative design that helps reduce dust accumulation. * This fan boasts a sleek bright gold finish that adds a touch of elegance to any room decor. * With a sweep size of 1200mm, it provides efficient air circulation for large spaces up to 250 sq ft. * Its powerful motor delivers silent yet effective cooling performance with high-speed operation of 370 RPM. * Equipped with a remote control, you can easily adjust the fan speed from the comfort of your seat. * The fan also includes features such as sleep mode, timer function, and boost mode for added convenience. * Energy efficient, the Usha Bellissa ceiling fan is designed to consume less power while delivering superior performance. * Maintenance free, its goodbye dust technology ensures easy cleaning without the use of water or harsh chemicals. * Installation is simple with included mounting hardware and instructions. * Experience unmatched style, performance, and ease of use with the Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold)."
  },
  {
    "_id": "62da57fa863ba7c37a1315dd",
    "title": "Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan",
    "description": "Product Name: Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan Description: Introducing the Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan, designed to inspire your child's imagination while keeping them cool. This fan is perfect for children who love Barbie dolls and dream of becoming anything they want to be. With its stylish and colorful design, it will add a touch of fun and excitement to any room. The fan features a blade span of 1200mm, providing efficient air circulation to keep your child comfortable even during hot summer days. It has a high-speed motor that ensures quiet operation, so it won't disturb your child's sleep or playtime. The fan also comes with a remote control, allowing you to easily adjust the speed and mode from anywhere in the room. Safety is a top priority with this ceiling fan. It is equipped with a sturdy construction and a stable mounting system to prevent accidents. The blades are made of durable plastic material, ensuring long-lasting use. Plus, the fan is easy to install, making it convenient for parents. This ceiling fan is not only functional but also decorative. Its vibrant colors and Barbie-themed design make it an attractive addition to your child's bedroom or playroom. It is suitable for kids aged three years old and above. In summary, the Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan is a fantastic choice if you want to combine style, safety, and functionality in one product. Order now and let your child's dreams take flight!"
  },
  {
    "_id": "62da57fa863ba7c37a1315e1",
    "title": "Usha Striker Plus 1200mm Energy Saving Ceiling Fan (White)",
    "description": "Product Name: Usha Striker Plus 1200mm Energy Saving Ceiling Fan (White) Description: Introducing the Usha Striker Plus 1200mm Energy Saving Ceiling Fan, now available in a sleek white finish. This fan is designed to deliver powerful airflow while keeping energy consumption low, making it an ideal choice for any room in your home or office. Key Features: * Energy-saving motor: The fan's high-performance motor consumes less power compared to conventional fans, helping you save on electricity bills without compromising on comfort. * Large blade sweep size: With a blade sweep of 1200mm, this ceiling fan provides wide coverage and ensures efficient cooling throughout the room. * Durable build: Constructed with high-quality materials, this fan boasts long-lasting performance and durability, ensuring reliable operation year after year. * Whisper-quiet operation: Equipped with aerodynamically designed blades, this fan operates silently, providing uninterrupted relaxation and productivity. * Easy installation: Compatible with both standard and sloped ceilings, this fan features hassle-free mounting options for easy setup. * Attractive design: Featuring elegant curves and a clean white finish, this fan complements various decor styles and adds a touch of sophistication to any space. Specifications: * Brand: Usha * Model name: Striker Plus * Blade span: 1200mm * Motor type: Energy saving * Colour: White * Warranty: Please check with the manufacturer for warranty details Note: Always refer to the user manual provided by the manufacturer for proper usage instructions, maintenance tips, and safety guidelines."
  },
  {
    "_id": "62da57fa863ba7c37a1315e5",
    "title": "Usha Energia ISI 1400mm Energy Saving Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Energia ISI 1400mm Energy Saving Ceiling Fan (Rich White) Description: Introducing the Usha Energia ISI 1400mm Energy Saving Ceiling Fan, now available in Rich White. This fan is designed to deliver high-quality performance while helping you save energy and money on your electricity bills. With its impressive air delivery of 230 CMM, this fan ensures efficient cooling even in large rooms up to 160 sq ft. The Usha Energia ceiling fan features an aerodynamic design with swept aluminum blades that are engineered for optimal airflow and reduced power consumption. It also comes equipped with a powerful motor that operates quietly, ensuring comfortable and peaceful indoor environments. This fan boasts a sleek and modern design, making it a stylish addition to any room décor. Its premium finish adds a touch of elegance and sophistication, complementing both traditional and contemporary spaces. Furthermore, the fan's sturdy construction ensures long-lasting durability, providing reliable operation year after year. Key Features: * ISI certified for quality assurance * Aerodynamically designed swept aluminum blades * High air delivery of 230 CMM * Powerful motor for quiet and efficient operation * Modern and elegant design in Rich White color * Suitable for large rooms up to 160 sq ft * Long-lasting durability Whether you're looking to upgrade your home or office space, the Usha Energia ISI 1400mm Energy Saving Ceiling Fan is an excellent choice. Experience superior comfort, style, and savings today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315ea",
    "title": "Usha Nabila 1200mm Energy Saving Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Nabila 1200mm Energy Saving Ceiling Fan (Rich Brown) Description: Introducing the Usha Nabila 1200mm Energy Saving Ceiling Fan, featuring a rich brown finish to complement any home decor. This fan is designed with energy efficiency in mind, using advanced technology to reduce power consumption without sacrificing performance. With a sweep size of 1200mm, it provides efficient air circulation for medium-sized rooms. Key Features: * Rich brown color adds warmth and style to your room * Advanced aerodynamic design ensures optimal air delivery while reducing noise levels * High-quality motor delivers powerful and consistent airflow * Specially treated blades prevent rust and corrosion over time * Energy saving mode reduces power usage by up to 35% compared to traditional fans * Includes a remote control for easy operation from anywhere in the room * Durable build quality ensures long-lasting use and minimal maintenance requirements * Suitable for ceiling heights between 2.8m - 3.4m * Easy installation process with all necessary hardware included Specifications: * Brand: Usha * Model: Nabila * Color: Rich Brown * Blade Material: Aluminum * Motor Type: Single phase induction motor * Speed Control: Remote controlled * Warranty: Contact manufacturer for details This Usha Nabila 1200mm Energy Saving Ceiling Fan is perfect for those looking to upgrade their existing fan or add a stylish yet functional piece to their space. Its energy-saving features make it an environmentally friendly choice, while its durable build and warranty ensure peace of mind. Order yours today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315f4",
    "title": "Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White) Product Description: * Introduction: Introduce the product, its brand name \"Usha\" which is known for quality fans, and highlight its key feature - universal fitting. Mention the color option available - Rich white. * Size & Dimensions: Specify the size of the fan to be 1400mm, suitable for medium-large sized rooms. Mention the dimensions of the fan to give an idea about its space requirement. * Materials Used: List down the materials used in constructing the fan such as high-quality plastic and metal, ensuring durability and long life. * Motor Type: Highlight the powerful motor with efficient air delivery, providing excellent cooling performance even at low speeds. Also, mention the noise level to ensure quiet operation. * Blade Design: Describe the number and design of blades, including their aerodynamic shape for optimal airflow and energy efficiency. Mention any additional features like rust-free or anti-dust properties. * Control Options: Explain the control options available, such as pull cords, wall controls or remote control, making it convenient for users to operate from anywhere in the room. * Installation: Provide details regarding installation process, compatibility with different ceiling types, and if professional installation is recommended. * Additional Features: If applicable, include other notable features such as summer-winter function, LED light kit, oscillating mechanism etc. * Conclusion: Summarize the main benefits and selling points of the Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White), emphasizing on its versatility and functionality. Note: SEO Keywords are not included in this format but suggested words could be 'Usha', 'Ceiling Fan', 'Universal Fitting', 'Rich White', 'Powerful Motor', 'Aerodynamic Blades' etc."
  },
  {
    "_id": "62da57fa863ba7c37a1315c3",
    "title": "Usha Bloom Primrose Sweep 1250mm Ceiling Fan (White)",
    "description": "Product Name: Usha Bloom Primrose Sweep 1250mm Ceiling Fan (White) Description: The Usha Bloom Primrose Sweep 1250mm Ceiling Fan is a high-quality, elegant, and efficient cooling solution for your home or office. This fan features a sleek white design with curved blades that are designed to provide maximum air delivery while maintaining a quiet operation. With a sweep size of 1250mm, it covers a large area, making it perfect for living rooms, bedrooms, and other spacious areas. Key Features: * Elegant white design with curved blades adds a touch of sophistication to any room * Large 1250mm sweep provides powerful air circulation for effective cooling * Quiet operation allows you to enjoy the cool breeze without disturbing noise * Energy-efficient motor ensures long-lasting performance and savings on electricity bills * Easy installation and maintenance for added convenience Specifications: * Brand: Usha * Model: Bloom Primrose Sweep * Color: White * Blade Material: Plastic * Motor Type: Single Phase Induction Motor * Speed Control: Regulator Included * Warranty: Contact Manufacturer For Details This ceiling fan is ideal for those looking for an energy-efficient and stylish cooling option for their homes or offices. Its quiet operation and easy installation make it a convenient choice for anyone seeking a hassle-free experience. Order now and elevate your space with the Usha Bloom Primrose Sweep 1250mm Ceiling Fan!"
  },
  {
    "_id": "62da57fa863ba7c37a1315d4",
    "title": "Usha Super Striker 1200mm Goodbye Dust Ceiling Fan (Mist Metallic Green)",
    "description": "Product Name: Usha Super Striker 1200mm Goodbye Dust Ceiling Fan (Mist Metallic Green) Description: Introducing the Usha Super Striker 1200mm Goodbye Dust Ceiling Fan, now available in Mist Metallic Green. This fan is designed to keep your space cool and comfortable while also helping to reduce dust accumulation. With its powerful motor and aerodynamic design, it delivers high-speed air circulation for efficient cooling. Features: * 1200mm sweep size provides wide coverage and excellent air delivery * Goodbye Dust technology helps prevent dust buildup on blades * Attractive Mist Metallic Green color adds a touch of style to any room * High-performance motor ensures long-lasting durability and quiet operation * Aerodynamically designed blades minimize noise and maximize airflow * Ideal for large rooms such as living rooms or bedrooms * Easy to install with included mounting hardware Specifications: * Brand: Usha * Model Number: Super Striker * Color: Mist Metallic Green * Sweep Size: 1200mm * Warranty: Please refer to manufacturer's website for warranty details This ceiling fan is perfect for those who want a stylish and functional addition to their home. Its unique features make it stand out from other fans on the market, making it an ideal choice for anyone looking to upgrade their current fan. Order yours today and experience the difference!"
  },
  {
    "_id": "62da57fa863ba7c37a1315
Order yours today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315f3",
    "title": "Usha Striker Millennium 1200mm Universal Ceiling Fan (Ultra Marine Blue)",
    "description": "Product Name: Usha Striker Millennium 1200mm Universal Ceiling Fan (Ultra Marine Blue) Description: Introducing the Usha Striker Millennium 1200mm Universal Ceiling Fan, featuring an Ultra Marine Blue color finish. This fan is designed to deliver powerful air circulation while adding a touch of style to your room decor. Its universal mounting system makes it suitable for both standard and sloped ceilings. Key Features: * Size: 1200mm (48 inches) sweep diameter, ideal for medium-sized rooms up to 150 sq ft. * Motor Type: High-performance motor with superior wind flow technology ensures efficient cooling even at low speeds. * Blade Material: Durable, high-quality plastic blades offer long-lasting performance and require minimal maintenance. * Color: Attractive Ultra Marine Blue finish complements modern interiors beautifully. * Mounting System: Includes a universal mounting bracket compatible with flat and angled surfaces, making installation easy and versatile. * Energy Efficiency: Designed for energy efficiency without compromising its cooling capabilities. * Noise Level: Smooth operation with reduced noise levels provides maximum comfort. This ceiling fan from Usha's Striker series offers excellent value for money due to its robust build quality and stylish appearance. With simple yet elegant aesthetics, the Ultra Marine Blue model adds a vibrant splash of color to any space. Enjoy optimal airflow throughout your living or workspace with ease and convenience. Please note that this product does not include warranty details; kindly contact the seller directly for more information regarding after-sales support. Keyword optimization has been considered when writing the description but may still require further adjustment based on specific SEO requirements."
  },
  {
    "_id": "62da57fa863ba7c37a131622",
    "title": "Usha Swift 1400mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Swift 1400mm Universal Ceiling Fan (Rich Brown) Description: Introducing the Usha Swift 1400mm Universal Ceiling Fan, featuring a rich brown color finish. This fan is designed to deliver powerful air circulation while maintaining a quiet operation, making it ideal for use in living rooms, bedrooms, or any other space up to 250 sq ft. The Usha Swift features aerodynamically designed blades with a sweep of 1400mm, providing efficient cooling performance at low noise levels. Its universal mounting system allows for easy installation in both standard and sloped ceilings, making it suitable for various room layouts. This ceiling fan comes equipped with a high-speed motor that ensures quick start-up and consistent performance even after long hours of usage. It also has an energy-efficient design that helps reduce electricity bills without compromising on comfort. Additional features include a pull cord switch for easy speed control, three different speed settings, and a built-in safety regulator for added peace of mind. The fan's sturdy construction and durable materials ensure longevity, making it a reliable choice for your home or office. Key Features: * Sweep size: 1400mm * Color: Rich Brown * Aerodynamic blade design * High-speed motor * Universal mounting system * Pull cord switch * Three-speed setting * Energy-efficient design * Built-in safety regulator * Sturdy construction and durable materials Specifications: * Brand: Usha * Model Number: Swift * Blade Material: Aluminum * Motor Type: High-Speed * Mounting System: Universal * Speed Settings: 3 * Switch Type: Pull Cord * Voltage: 220V - 240V * Warranty: Please check manufacturer warranty details Note: Always refer to the manufacturer website or contact their customer service department for specific warranty information regarding their products."
  },
  {
    "_id": "62da57fa863ba7c37a1315fb",
    "title": "Usha Allure Deluxe 900mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Allure Deluxe 903R Rich Brown Universal Ceiling Fan Description: Introducing the Usha Allure Deluxe 903R, a universal ceiling fan with a rich brown finish. This elegant and stylish fan is designed to complement any decor while providing efficient cooling for your space. With its powerful motor and aerodynamic blades, it ensures excellent air delivery and circulation, making it perfect for large rooms up to 180 sq. ft. Key Features: * Dimensions: Diameter - 900 mm, Height - 275 mm * Finish: Rich Brown * Motor Type: High-performance, double ball bearing * Number of Blades: 3 * Speed Control: 3 speed settings with summer-winter feature * Warranty: 2 years on the motor and 1 year on the fan The Usha Allure Deluxe features a high-performance, double ball bearing motor that ensures long life and silent oper
for optimal air circulation * Powerful motor for whisper-quiet performance * Three-speed settings for customized cooling needs * Easy installation and maintenance Specifications: * Brand: Usha * Model: Nova DLX * Blade Span: 1400mm * Finish: Rich Brown * Motor Type: Single Phase Induction Motor * Speed Settings: High, Medium, Low * Controls: Pull Chain or Remote Control (sold separately) * Warranty: Please check with manufacturer Technical Details: * Voltage: 230V AC * RPM: 350 / 310 / 270 * Air Delivery: 230 CMH (Cubic Meter per Hour) * Number of Blades: 3 * Shaft Material: Aluminum Alloy * Weight: 6kg The Usha Nova DLX 1400mm Universal Ceiling Fan is perfect for living rooms, bedrooms, offices, and other medium to large spaces where efficient and stylish cooling is required. Order yours today and experience superior comfort and elegant aesthetics!"
  },
  {
    "_id": "62da57fa863ba7c37a13161f",
    "title": "Usha Sonata 1200mm Universal Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Sonata 1200mm Universal Ceiling Fan (Rich White) Description: Introducing the Usha Sonata 1200mm Universal Ceiling Fan, now available in a rich white finish. This fan is designed to deliver powerful air circulation while adding style and elegance to your room decor. With its universal fit design, it's suitable for any room size, making it an ideal choice for both residential and commercial spaces. Key Features: * Motor Type: Energy-efficient motor ensures high performance with low power consumption, providing long-lasting durability. * Blade Sweep: A generous blade sweep of 1200mm delivers superior cooling and airflow throughout the room. * Design: Crafted in a sleek and modern style, this ceiling fan adds sophistication and class to any space. Its rich white color complements various interior designs. * Number of Blades: Equipped with three sturdy blades, ensuring optimal balance and reducing noise during operation. * Control Options: Includes a pull cord switch for easy control and convenience. * Suitability: Ideal for rooms up to 150 sq ft, perfect for living areas, bedrooms, or offices. * Warranty: Contact manufacturer for warranty details. SEO Keywords: Usha Sonata Ceiling Fan, Rich White Finish, Powerful Air Circulation, Energy Efficient, Modern Style, Generous Blade Sweep, Durable Motor, Three Sturdy Blades, Pull Cord Switch, Room Cooling Solution, High Performance, Low Noise Operation, Residential & Commercial Use."
  },
  {
    "_id": "62da57fa863ba7c37a131620",
    "title": "Usha Sonata 1200mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Sonata 1200mm Universal Ceiling Fan (Rich Brown) Description: Introducing the Usha Sonata 1200mm Universal Ceiling Fan, now available in a rich brown finish to complement your home decor. This fan is designed for universal use, making it suitable for any room in your house. With its impressive 1200mm sweep size, the Usha Sonata provides efficient air circulation to keep you cool during hot summer months. Its high-speed performance of up to 380 RPM ensures quick cooling, while its low-speed setting helps maintain comfortable temperatures all year round. The fan features an aerodynamic design with swept back aluminum blades that reduce aircutting noise, providing a peaceful environment for sleeping or working. It also has a double ball bearing mechanism for long-lasting durability and silent operation. Additionally, the Usha Sonata comes with a two-way adjustable mounting system, allowing for easy installation on both standard and sloped ceilings. Key Features: * Suitable for all rooms * 1200mm sweep size for efficient air circulation * High-speed performance of up to 380 RPM * Low-noise operation due to aerodynamic design * Double ball bearing mechanism for longevity * Two-way adjustable mounting system for versatile installation * Rich brown color adds elegance and style to any space This Usha ceiling fan offers excellent value for money and promises reliable performance backed by the trusted reputation of Usha brand. Upgrade your living space with the modern design and powerful functionality of the Usha Sonata 1200mm Universal Ceiling Fan (Rich Brown)."
  },
  {
    "_id": "62da57fa863ba7c37a1315c4",
    "title": "Usha Bloom Primrose Sweep 1250mm Ceiling Fan (Golden And Cherry)",
    "description": "Product Name: Usha Bloom Primrose Sweep 1250mm Ceiling Fan (Golden and Cherry) Product Description: * Type: Ceiling fan * Brand: Usha * Model: Bloom Primrose * Blade span: 1250mm (49.2 inches) * Finish: Golden and Cherry * Materials: High-quality metal and wood * Controls: Pull cord regulation * Warranty: Contact manufacturer for details * Special features: Energy-efficient motor, stylish design, quiet operation * Applicable room size: Medium to large rooms * Voltage: 230V AC, 50Hz * Weight: 7kg * Additional accessories included: None * Other features: Decorative and functional, provides smooth airflow, easy installation This ceiling fan from Usha is an excellent choice for those who want a decorative yet efficient cooling solution for their homes or offices. With its elegant golden and cherry finish, the fan adds a touch of sophistication to any space while providing powerful air circulation. The high-quality materials used in construction ensure durability and long-lasting performance. The energy-efficient motor ensures low power consumption without compromising on the fan's efficiency. It comes with pull cord controls for ease of use, making it simple to adjust the speed according to your comfort level. The fan has been designed to operate quietly, ensuring minimal noise disturbance. With a blade sweep of 1250mm, the Usha Bloom Primrose fan is suitable for medium to large-sized rooms. Its stylish design complements both modern and traditional decors, making it a versatile addition to any space. Installation is straightforward and hassle-free, thanks to clear instructions provided by the manufacturer. Overall, the Usha Bloom Primrose Sweep 1250mm Ceiling Fan (Golden and Cherry) offers great value for money, combining style and functionality at an affordable price point."
  },
  {
    "_id": "62da57fa863ba7c37a1315c7",
    "title": "Usha Bloom Magnolia Sweep 1250mm Ceiling Fan (White)",
    "description": "Product Name: Usha Bloom Magnolia Sweep 1250mm Ceiling Fan (White) Description: Introducing the Usha Bloom Magnolia Sweep 1250mm Ceiling Fan, a stylish and efficient addition to any room. This fan boasts a sleek white finish and elegant magnolia blades that complement modern decor while providing powerful air circulation. With a sweep of 1250mm, it covers large spaces with ease, ensuring consistent comfort throughout your home or office. Key Features: * Stylish design with a clean white finish and magnolia blades * Powerful 75-watt motor for effective air movement * Ideal for rooms up to 144 sq ft * High-speed operation ensures quick cooling * Low noise level for peaceful environment * Easy installation with included hardware * Energy-efficient performance saves electricity costs * Durable construction built for long-lasting use * Rust-resistant materials ensure longevity Specifications: * Brand: Usha * Model Number: Bloom Magnolia Sweep 1250mm * Colour: White * Blade Material: Aluminium * Motor Type: Single Phase Induction Motor * Controls: Pull Chain Regulator * Warranty: Please refer to manufacturer's warranty policy * Dimensions: Length - 1250mm, Height - 360mm, Width - 390mm * Weight: 8kg Note: Kindly check with the seller regarding warranty details before purchasing."
  },
  {
    "_id": "62da57fa863ba7c37a1315c9",
    "title": "Usha Striker Galaxy 1200mm Goodbye Dust Ceiling Fan (Corn Silk)",
    "description": "Product Name: Usha Striker Galaxy 1200mm Goodbye Dust Ceiling Fan (Corn Silk) Description: * Brand: Usha * Model: Striker Galaxy * Blade Sweep: 1200mm * Color: Corn Silk * Type: Ceiling Fan * Special Feature: Goodbye Dust technology for easy cleaning * Number of blades: 3 * Speed control: Yes, with regulator * Warranty: Not specified * Energy efficient motor ensures low power consumption. * Ribbed aluminium blades provide powerful air delivery and longer life. * Decorative and sturdy design suitable for all types of interiors. * Double ball bearing for smooth and noiseless operation. * Easy to install and maintain. * Comes with a stylish regulator for speed control. * Meets Indian safety standards (ISI marked). Keywords: Usha ceiling fan, Striker Galaxy, 1200mm blade sweep, corn silk color, goodbye dust technology, energy efficient, ribbed aluminum blades, double ball bearing, speed control regulator, ISI marked."
  },
  {
    "_id": "62da57fa863ba7c37a1315ce",
    "title": "Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Mist Metallic Green)",
    "description": "Product Name: Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Mist Metallic Green) Description: Introducing the Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan, now available in Mist Metallic Green. This fan is designed to deliver powerful air circulation while keeping your space dust-free. With its advanced Goodbye Dust technology, you can say goodbye to regular cleaning and maintenance hassles. Key Features: * Advanced Goodbye Dust Technology: Specially treated anti-static ABS blades reduce dust accumulation by up to 50%. * Powerful Air Circulation: Delivers high-speed cooling with an impressive air delivery of 230 cubic meters per minute. * Energy Efficient: Consumes only 75 watts of power for energy savings without compromising performance. * Long Life Span: High-quality motor ensures long life and durability. * Sweep Size: The large sweep size of 1200mm provides wide coverage and efficient cooling even in larger spaces. * Modern Design: Attractive mist metallic green color adds a touch of sophistication to any room decor. * Easy Installation: Comes with a user manual and all necessary hardware for easy installation. * Warranty: Backed by a limited warranty from Usha, ensuring customer satisfaction and reliability. This ceiling fan is suitable for both residential and commercial use, making it perfect for homes, offices, schools, hospitals, and other public spaces. Order yours today and enjoy cool, clean air throughout the year!"
  },
  {
    "_id": "62da57fa863ba7c37a1315db",
    "title": "Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Truffle Gloss)",
    "description": "Product Name: Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Truffle Gloss) Description: Introducing the Usha Bellissa 1200mm Goodbye Dust Ceiling Fan, now available in a stunning Truffle Gloss finish. This fan is designed to deliver powerful air circulation while keeping your space dust-free. With its impressive 1200mm sweep size, it provides efficient cooling for large rooms up to 250 square feet. Key Features: * Goodbye Dust technology: Unique anti-dust airflow mechanism prevents accumulation of dust particles, ensuring cleaner and healthier indoor environment. * Powerful motor: High-performance motor with double ball bearings ensures smooth operation and long-lasting durability. * Energy efficiency: Engineered to consume less power without compromising performance, making it an ideal choice for eco-conscious consumers. * Stunning design: Attractive truffle gloss finish adds sophistication and elegance to any room decor. * Wide sweep size: Covers larger areas effectively with its 1200mm blade span, providing optimal comfort during hot summer months. * Easy installation: Comes with all necessary mounting hardware and instructions, allowing easy do-it-yourself setup. * Smooth operation: Delivers silent yet effective air movement even at high speeds, maintaining peaceful ambiance in living spaces. Specifications: * Brand: Usha * Model name: Bellissa * Sweep Size: 1200mm * Color: Truffle Gloss * Material: Aluminum blades with ABS plastic body * Motor Type: Double Ball Bearing * Speed Control: Regulator compatible * Warranty: Please check manufacturer's website or contact their customer service for warranty details Note: Kindly refer to the user manual provided by the manufacturer for proper usage, maintenance tips, troubleshooting guidelines, and safety precautions before operating the product. Always follow local regulations regarding ceiling fan installations and consult professionals if needed."
  },
  {
    "_id": "62da57fa863ba7c37a1315fd",
    "title": "Usha Allure Deluxe 600mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Allure Deluxe 600mm Universal Ceiling Fan (Rich Brown) Description: * Introducing the Usha Allure Deluxe 600mm Universal Ceiling Fan, featuring a rich brown finish to add a touch of elegance to any room. * This fan is designed for universal fitting and can be installed in rooms with ceiling heights ranging from 2.5m to 3.5m. * It comes equipped with a powerful motor that delivers airflow up to 210 CMM, ensuring consistent cooling throughout your space. * The energy-efficient BEE 5-star rating ensures reduced electricity consumption without compromising performance. * With its stylish design and high functionality, it's perfect for both residential and commercial use. * The fan features three speed settings, allowing you to adjust the level of comfort according to your needs. * Its silent operation makes it ideal for bedrooms or study areas where quietness is essential. * Easy to install and maintain, the Usha Allure Deluxe Universal Ceiling Fan also includes a pull cord switch for added convenience. * Upgrade your home decor while enjoying efficient cooling with the Usha Allure Deluxe 600mm Universal Ceiling Fan in Rich Brown."
  },
  {
    "_id": "62da57fa863ba7c37a131600",
    "title": "Usha Aster Plus 1200mm Universal Ceiling Fan (Rich Ivory)",
    "description": "Product Name: Usha Aster Plus 1200mm Universal Ceiling Fan (Rich Ivory) Description: Introducing the Usha Aster Plus 1200mm Universal Ceiling Fan, featuring a rich ivory finish. This fan is designed to deliver powerful air circulation while adding an elegant touch to your room's decor. Its universal mounting system makes it compatible with both standard and sloped ceilings, making it suitable for installation in various spaces. Key Features: * Motor Type: Energy-efficient motor ensures low power consumption without compromising performance. * Blade Sweep: With a sweep of 1200mm, this ceiling fan provides wide coverage, ensuring uniform cooling throughout the room. * Rich Ivory Finish: The beautiful rich ivory color complements modern interiors effortlessly and adds sophistication to any space. * Universal Mounting System: Allows easy installation on both flat and angled surfaces, providing versatility for different applications. * High Speed: Delivers impressive high-speed performance, effectively circulating air even in larger rooms. * Durable Material: Constructed from premium materials to ensure long-lasting durability and resistance to wear and tear over time. * Easy Assembly: Comes with clear instructions for quick assembly, enabling users to install their new fans efficiently. * Quiet Operation: Designed for whisper-quiet operation, allowing you to enjoy peaceful surroundings without unwanted noise disturbances. * Suitable Room Size: Ideal for medium to large living areas, bedrooms, or office spaces up to 250 sq ft. Note: Kindly refer to the user manual provided with the product for specifications, dimensions, warranty details, and maintenance guidelines. This will assist you in optimally utilizing your newly purchased ceiling fan."
  },
  {
    "_id": "62da57fa863ba7c37a131602",
    "title": "Usha Neo Plus 1200mm Universal Ceiling Fan (Rich Ivory)",
    "description": "Product Name: Usha Neo Plus 1200mm Universal Ceiling Fan (Rich Ivory) Description: Introducing the Usha Neo Plus 1200mm Universal Ceiling Fan, featuring a rich ivory finish. This fan is designed to deliver powerful air circulation while adding a touch of elegance to your space. Its universal fit makes it suitable for any room size or ceiling height. With a sweep size of 1200mm, this fan ensures maximum coverage and efficient cooling. Key Features: * Rich Ivory Finish: Adds an elegant touch to your decor while complementing various interiors. * Powerful Air Delivery: Equipped with high-speed aluminum blades that ensure optimal air delivery even at low speeds. * Energy Efficient Motor: Designed for long-lasting performance and reduced energy consumption, helping you save on electricity bills. * Whisper Quiet Operation: Experience smooth operation without disturbances due to its aerodynamically designed motor and blade structure. * Wide Range Compatibility: Suitable for all mountings, including standard, sloped, or angled ceilings, making it perfect for installation in living rooms, bedrooms, kitchens, and more. * Easy Installation: Includes a user manual and required hardware for easy DIY installation, saving time and effort. Specifications: * Brand: Usha * Model: Neo Plus * Size: 1200mm * Color: Rich Ivory * Material: Aluminum Blades, Plastic Body * Control Type: Pull Chain Regulator * Number of Speeds: 3 * RPM: 350 (Low), 450 (Medium), 600 (High) * Voltage: 220V - 240V AC, Single Phase * Warranty: Please check with manufacturer or seller Note: Always refer to the manufacturer's website or consult with their customer support team regarding warranty details."
  },
  {
    "_id": "62da57fa863ba7c37a131606",
    "title": "Usha Xavia 1200mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Xavia 1200mm Universal Ceiling Fan (Rich Brown) Description: * The Usha Xavia ceiling fan is designed with a universal fit, making it suitable for any room in your home or office. * Its rich brown color adds warmth and sophistication to your decor, while the sleek design complements both traditional and modern spaces. * With a size of 1200mm, this fan provides efficient air circulation to keep you cool during hot summer days. * It features a high-speed motor that ensures powerful performance, along with an aerodynamic blade design for reduced noise and energy consumption. * The fan also includes a remote control for easy operation from anywhere in the room. * Additionally, the Usha Xavia comes with a two-year warranty for added peace of mind. Note: This product description focuses on providing relevant information about the Usha Xavia ceiling fan, including its features and benefits. However, it does not include SEO keywords or warranty details as requested."
  },
  {
    "_id": "62da57fa863ba7c37a131608",
    "title": "Usha Trump Plus 1200mm Universal Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Trump Plus 1200mm Universal Ceiling Fan (Rich White) Description: Introducing the Usha Trump Plus 1200mm Universal Ceiling Fan, featuring a rich white finish to complement any decor. This fan is designed for universal use and comes with a large 1200mm sweep size, providing efficient air circulation throughout your space. Its powerful motor ensures smooth operation at low noise levels, making it perfect for bedrooms, living rooms, or offices. Key Features: * Universal fit design suitable for all types of ceilings * Large 1200mm sweep size for optimal air circulation * Powerful motor ensuring quiet and smooth operation * Rich white finish adds elegance and style to any room * Ideal for both residential and commercial spaces Specifications: * Brand: Usha * Model Number: Trump Plus * Size: 1200mm * Color: Rich White * Material: Metal * Warranty: Please contact manufacturer for warranty details Note: We strive to provide accurate and up-to-date descriptions; however, we recommend checking the manufacturer's website for further specifications and warranties before purchasing."
  },
  {
    "_id": "62da57fa863ba7c37a13160a",
    "title": "Usha Racer 1200mm Universal Ceiling Fan (Rich Red)",
    "description": "Product Name: Usha Racer 1200mm Universal Ceiling Fan (Rich Red) Description: Introducing the Usha Racer 1200mm Universal Ceiling Fan, now available in a stunning Rich Red finish. This fan is designed to deliver powerful air circulation while adding a touch of elegance to your space. With its universal compatibility, it's perfect for any room in your home or office. Features: * Motor: Equipped with an efficient motor that ensures silent operation and long-lasting performance. * Blades: Made from high-quality aluminum material, the blades are designed for optimal air delivery and durability. * Size: The 1200mm blade sweep provides extensive coverage, making it ideal for large rooms up to 144 sq ft. * Design: Its aerodynamic design not only enhances its appearance but also improves its efficiency and reduces noise levels. * Colour: Add a pop of colour to your decor with the vibrant Rich Red finish, which complements both modern and traditional interiors. * Control: Includes a pull cord switch for easy control and convenience. * Warranty: Although warranty details may vary by region, rest assured knowing you have purchased a reliable and durable product from a reputable brand like Usha. Keywords: Usha Racer ceiling fan, red ceiling fan, 1200mm ceiling fan, universal ceiling fan, Usha fans, quiet ceiling fan, elegant ceiling fan, energy-efficient ceiling fan, durable ceiling fan, high-performance ceiling fan, Indian brand ceiling fan."
  },
  {
    "_id": "62da57fa863ba7c37a13160e",
    "title": "Usha Striker 1400mm Universal Ceiling Fan (Matte Brown)",
    "description": "Product Name: Usha Striker 1400mm Universal Ceiling Fan (Matte Brown) Description: Introducing the Usha Striker 1400mm Universal Ceiling Fan, featuring a sleek matte brown finish. This fan is designed to deliver powerful air circulation while adding a touch of elegance to your space. With its universal mounting system, it's suitable for both standard and sloped ceilings up to 30 degrees. Key Features: * Size: 1400mm (56 inches) sweep diameter provides efficient cooling for large rooms * Finish: Matte brown color adds sophistication and complements any decor * Motor Type: High-performance motor ensures whisper-quiet operation and long lifespan * Blade Material: Durable plastic blades resist warping and ensure consistent performance over time * Included Accessories: Comes with a ball point fitting for easy installation and height adjustment * Warranty: Please refer to the manufacturer for warranty details Specifications: * Voltage: AC 220-240V * Power Consumption: 78W * Speed Control: Regulator compatible * RPM Range: 300-390RPM * Air Delivery: Up to 230 cubic meters per minute * Weight: Approximately 8kg This ceiling fan is perfect for living rooms, bedrooms, or other large spaces where effective cooling is required. Its stylish design makes it an excellent choice for modern homes, offices, or commercial establishments looking for high-quality ventilation solutions. Order now and experience unmatched comfort and style! SEO Keywords: Usha Striker ceiling fan, matte brown ceiling fan, 1400mm ceiling fan, universal ceiling fan, durable plastic blades, quiet operation, energy-efficient"
  },
  {
    "_id": "62da57fa863ba7c37a131615",
    "title": "Usha Striker 1200mm Universal Ceiling Fan (Matte Brown)",
    "description": "Product Name: Usha Striker 1200mm Universal Ceiling Fan (Matte Brown) Description: * Product Dimensions: Diameter - 1200mm, Height - 350mm * Material: High-quality plastic and metal * Finish: Matte brown * Motor Type: Energy-efficient AC motor with double ball bearing for smooth operation * Blades: 3 durable PVC blades with aerodynamic design for maximum air delivery * Speed Control: Regulator included for variable speed control * Warranty: N/A * Additional Features: Rust-resistant coating, low noise during operation, suitable for all room sizes. This Usha Striker 1200mm Universal Ceiling Fan is designed to deliver powerful cooling performance while maintaining an energy-efficient operation. Its matte brown finish adds style and elegance to any room decor. With its high-quality construction using robust materials like plastic and metal, the fan promises durability and longevity. The ceiling fan features an energy-efficient AC motor with double ball bearings that ensure smooth and quiet operation. It comes equipped with three durable PVC blades having an aerodynamic design that maximizes air delivery, providing efficient cooling throughout the space. For added convenience, the regulator allows you to adjust the fan's speed according to your preference. Additionally, it boasts rust-resistant coatings ensuring long-lasting use even in humid conditions. This versatile ceiling fan is ideal for rooms of various sizes, making it perfect for both residential and commercial spaces."
  },
]

# Preprocess and encode the descriptions
descriptions = [product['title'] for product in products]
encoded_descriptions = model.encode(descriptions)

# Function to recommend a product based on a query
def recommend_product(query):
    # Preprocess and encode the query
    query_embedding = model.encode([query])

    # Compute similarities
    similarities = cosine_similarity(query_embedding, encoded_descriptions)

    # Find the index of the highest similarity score
    recommended_index = similarities.argmax()

    # Return the recommended product
    return products[recommended_index]

# Example query
query = "fan 1200mm grey"
recommended_product = recommend_product(query)
print(f"Recommended Product: {recommended_product['title']}")
# Out:
# Recommended Product: Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Frosty Grey)

# %%
# !pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.9 MB/s eta 0:00:00
# ...
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=72ae596d93735bb01bc16fccca470256143aa7fab6dc2a28b44ce4553339b553
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# ...

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Your dataset
products = [

  {
    "_id": "62da57fa863ba7c37a1315cf",
    "title": "Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Frosty Grey)",
    "description": "Product Name: Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Frosty Grey) Description: Introducing the Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan, featuring an elegant frosty grey finish. This fan is designed to keep you cool while also maintaining a clean home environment with its unique Goodbye Dust technology. Its 1200mm sweep size ensures powerful air delivery for effective cooling in large rooms up to 180 sq ft. Key Features: * Frosty Grey Finish: Adds a modern touch to your decor while complementing various color schemes. * Goodbye Dust Technology: Specially treated blades repel dust accumulation, making cleaning easier and less frequent. * Powerful Air Delivery: With a 1200mm sweep size, enjoy efficient cooling even in larger spaces. * High-Performance Motor: Ensures smooth operation and long lifespan, delivering reliable performance year after year. * Ribbed Aluminium Blades: Designed for optimal balance between style and functionality. * Energy Efficient: Consumes low power without compromising on performance or durability. * Easy Installation: Compatible with standard ceiling mounts, allowing easy installation for DIY enthusiasts. * Wide Range of Speeds: Offers multiple speed settings, enabling customized comfort based on personal preferences. This Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan combines sleek design, innovative features, and dependable performance. Experience enhanced air circulation and improved indoor air quality today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315da",
    "title": "Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold)",
    "description": "Product Name: Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold) Description: * Introducing the Usha Bellissa 1200mm Goodbye Dust Ceiling Fan, featuring an innovative design that helps reduce dust accumulation. * This fan boasts a sleek bright gold finish that adds a touch of elegance to any room decor. * With a sweep size of 1200mm, it provides efficient air circulation for large spaces up to 250 sq ft. * Its powerful motor delivers silent yet effective cooling performance with high-speed operation of 370 RPM. * Equipped with a remote control, you can easily adjust the fan speed from the comfort of your seat. * The fan also includes features such as sleep mode, timer function, and boost mode for added convenience. * Energy efficient, the Usha Bellissa ceiling fan is designed to consume less power while delivering superior performance. * Maintenance free, its goodbye dust technology ensures easy cleaning without the use of water or harsh chemicals. * Installation is simple with included mounting hardware and instructions. * Experience unmatched style, performance, and ease of use with the Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold)."
  },
  {
    "_id": "62da57fa863ba7c37a1315dd",
    "title": "Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan",
    "description": "Product Name: Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan Description: Introducing the Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan, designed to inspire your child's imagination while keeping them cool. This fan is perfect for children who love Barbie dolls and dream of becoming anything they want to be. With its stylish and colorful design, it will add a touch of fun and excitement to any room. The fan features a blade span of 1200mm, providing efficient air circulation to keep your child comfortable even during hot summer days. It has a high-speed motor that ensures quiet operation, so it won't disturb your child's sleep or playtime. The fan also comes with a remote control, allowing you to easily adjust the speed and mode from anywhere in the room. Safety is a top priority with this ceiling fan. It is equipped with a sturdy construction and a stable mounting system to prevent accidents. The blades are made of durable plastic material, ensuring long-lasting use. Plus, the fan is easy to install, making it convenient for parents. This ceiling fan is not only functional but also decorative. Its vibrant colors and Barbie-themed design make it an attractive addition to your child's bedroom or playroom. It is suitable for kids aged three years old and above. In summary, the Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan is a fantastic choice if you want to combine style, safety, and functionality in one product. Order now and let your child's dreams take flight!"
  },
  {
    "_id": "62da57fa863ba7c37a1315e1",
    "title": "Usha Striker Plus 1200mm Energy Saving Ceiling Fan (White)",
    "description": "Product Name: Usha Striker Plus 1200mm Energy Saving Ceiling Fan (White) Description: Introducing the Usha Striker Plus 1200mm Energy Saving Ceiling Fan, now available in a sleek white finish. This fan is designed to deliver powerful airflow while keeping energy consumption low, making it an ideal choice for any room in your home or office. Key Features: * Energy-saving motor: The fan's high-performance motor consumes less power compared to conventional fans, helping you save on electricity bills without compromising on comfort. * Large blade sweep size: With a blade sweep of 1200mm, this ceiling fan provides wide coverage and ensures efficient cooling throughout the room. * Durable build: Constructed with high-quality materials, this fan boasts long-lasting performance and durability, ensuring reliable operation year after year. * Whisper-quiet operation: Equipped with aerodynamically designed blades, this fan operates silently, providing uninterrupted relaxation and productivity. * Easy installation: Compatible with both standard and sloped ceilings, this fan features hassle-free mounting options for easy setup. * Attractive design: Featuring elegant curves and a clean white finish, this fan complements various decor styles and adds a touch of sophistication to any space. Specifications: * Brand: Usha * Model name: Striker Plus * Blade span: 1200mm * Motor type: Energy saving * Colour: White * Warranty: Please check with the manufacturer for warranty details Note: Always refer to the user manual provided by the manufacturer for proper usage instructions, maintenance tips, and safety guidelines."
  },
  {
    "_id": "62da57fa863ba7c37a1315e5",
    "title": "Usha Energia ISI 1400mm Energy Saving Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Energia ISI 1400mm Energy Saving Ceiling Fan (Rich White) Description: Introducing the Usha Energia ISI 1400mm Energy Saving Ceiling Fan, now available in Rich White. This fan is designed to deliver high-quality performance while helping you save energy and money on your electricity bills. With its impressive air delivery of 230 CMM, this fan ensures efficient cooling even in large rooms up to 160 sq ft. The Usha Energia ceiling fan features an aerodynamic design with swept aluminum blades that are engineered for optimal airflow and reduced power consumption. It also comes equipped with a powerful motor that operates quietly, ensuring comfortable and peaceful indoor environments. This fan boasts a sleek and modern design, making it a stylish addition to any room décor. Its premium finish adds a touch of elegance and sophistication, complementing both traditional and contemporary spaces. Furthermore, the fan's sturdy construction ensures long-lasting durability, providing reliable operation year after year. Key Features: * ISI certified for quality assurance * Aerodynamically designed swept aluminum blades * High air delivery of 230 CMM * Powerful motor for quiet and efficient operation * Modern and elegant design in Rich White color * Suitable for large rooms up to 160 sq ft * Long-lasting durability Whether you're looking to upgrade your home or office space, the Usha Energia ISI 1400mm Energy Saving Ceiling Fan is an excellent choice. Experience superior comfort, style, and savings today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315ea",
    "title": "Usha Nabila 1200mm Energy Saving Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Nabila 1200mm Energy Saving Ceiling Fan (Rich Brown) Description: Introducing the Usha Nabila 1200mm Energy Saving Ceiling Fan, featuring a rich brown finish to complement any home decor. This fan is designed with energy efficiency in mind, using advanced technology to reduce power consumption without sacrificing performance. With a sweep size of 1200mm, it provides efficient air circulation for medium-sized rooms. Key Features: * Rich brown color adds warmth and style to your room * Advanced aerodynamic design ensures optimal air delivery while reducing noise levels * High-quality motor delivers powerful and consistent airflow * Specially treated blades prevent rust and corrosion over time * Energy saving mode reduces power usage by up to 35% compared to traditional fans * Includes a remote control for easy operation from anywhere in the room * Durable build quality ensures long-lasting use and minimal maintenance requirements * Suitable for ceiling heights between 2.8m - 3.4m * Easy installation process with all necessary hardware included Specifications: * Brand: Usha * Model: Nabila * Color: Rich Brown * Blade Material: Aluminum * Motor Type: Single phase induction motor * Speed Control: Remote controlled * Warranty: Contact manufacturer for details This Usha Nabila 1200mm Energy Saving Ceiling Fan is perfect for those looking to upgrade their existing fan or add a stylish yet functional piece to their space. Its energy-saving features make it an environmentally friendly choice, while its durable build and warranty ensure peace of mind. Order yours today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315f4",
    "title": "Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White) Product Description: * Introduction: Introduce the product, its brand name \"Usha\" which is known for quality fans, and highlight its key feature - universal fitting. Mention the color option available - Rich white. * Size & Dimensions: Specify the size of the fan to be 1400mm, suitable for medium-large sized rooms. Mention the dimensions of the fan to give an idea about its space requirement. * Materials Used: List down the materials used in constructing the fan such as high-quality plastic and metal, ensuring durability and long life. * Motor Type: Highlight the powerful motor with efficient air delivery, providing excellent cooling performance even at low speeds. Also, mention the noise level to ensure quiet operation. * Blade Design: Describe the number and design of blades, including their aerodynamic shape for optimal airflow and energy efficiency. Mention any additional features like rust-free or anti-dust properties. * Control Options: Explain the control options available, such as pull cords, wall controls or remote control, making it convenient for users to operate from anywhere in the room. * Installation: Provide details regarding installation process, compatibility with different ceiling types, and if professional installation is recommended. * Additional Features: If applicable, include other notable features such as summer-winter function, LED light kit, oscillating mechanism etc. * Conclusion: Summarize the main benefits and selling points of the Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich
Order yours today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315d7",
    "title": "Usha Elsa 1200mm Goodbye Dust Ceiling Fan (Copper Gold)",
    "description": "Product Name: Usha Elsa 1200mm Goodbye Dust Ceiling Fan (Copper Gold) Description: Introducing the Usha Elsa 1200mm Goodbye Dust Ceiling Fan, now available in an elegant Copper Gold finish. This fan is designed to keep your space cool while keeping dust away, making it perfect for those who suffer from allergies or asthma. With its powerful motor, the Usha Elsa provides efficient air circulation, ensuring that every corner of the room stays comfortable even during the hottest summer days. The Goodbye Dust feature ensures that the blades are specially treated with a coating that repels dust, reducing the frequency of cleaning required. Its 1200mm sweep diameter makes it suitable for medium-sized rooms, providing optimal coverage and performance. Additionally, the fan's sleek design and high-quality construction make it a stylish addition to any home or office decor. It also comes with a remote control, allowing you to adjust the speed settings and switch off the fan without having to get up from your seat. Key Features: * Powerful motor for efficient air circulation * Specialized Goodbye Dust treatment for reduced cleaning frequency * Suitable for medium-sized rooms with a 1200mm sweep diameter * Sleek design and high-quality construction * Remote control included for added convenience * Available in an attractive Copper Gold finish."
  },
  {
    "_id": "62da57fa863ba7c37a131613",
    "title": "Usha Striker 900mm Universal Ceiling Fan (Rich Ivory)",
    "description": "Product Name: Usha Striker 900mm Universal Ceiling Fan (Rich Ivory) Description: Introducing the Usha Striker 900mm Universal Ceiling Fan, featuring a rich ivory finish that adds elegance to any room. This fan is designed for universal use, making it suitable for both residential and commercial spaces. With a size of 900mm, it provides efficient air circulation, ensuring consistent comfort throughout your space. Key Features: * Rich ivory color for an elegant look * Suitable for both indoor and outdoor use * High-performance motor for powerful air delivery * Energy-efficient operation with low noise levels * Easy installation process * Durable build quality for long-lasting performance Specifications: * Size: 900mm * Finish: Rich Ivory * Material: Metal * Motor Type: High Performance * Warranty: N/A This ceiling fan from Usha is perfect for those looking for reliable and stylish cooling solution. Its sleek design, combined with its powerful performance, makes it an excellent choice for large rooms or areas where effective air circulation is essential. Whether you're using it at home or in a commercial setting, the Usha Striker 900mm Universal Ceiling Fan will not disappoint. Order yours today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315f3",
    "title": "Usha Striker Millennium 1200mm Universal Ceiling Fan (Ultra Marine Blue)",
    "description": "Product Name: Usha Striker Millennium 1200mm Universal Ceiling Fan (Ultra Marine Blue) Description: Introducing the Usha Striker Millennium 1200mm Universal Ceiling Fan, featuring an Ultra Marine Blue color finish. This fan is designed to deliver powerful air circulation while adding a touch of style to your room decor. Its universal mounting system makes it suitable for both standard and sloped ceilings. Key Features: * Size: 1200mm (48 inches) sweep diameter, ideal for medium-sized rooms up to 150 sq ft. * Motor Type: High-performance motor with superior wind flow technology ensures efficient cooling even at low speeds. * Blade Material: Durable, high-quality plastic blades offer long-lasting performance and require minimal maintenance. * Color: Attractive Ultra Marine Blue finish complements modern interiors beautifully. * Mounting System: Includes a universal mounting bracket compatible with flat and angled surfaces, making installation easy and versatile. * Energy Efficiency: Designed for energy efficiency without compromising its cooling capabilities. * Noise Level: Smooth operation with reduced noise levels provides maximum comfort. This ceiling fan from Usha's Striker series offers excellent value for money due to its robust build quality and stylish appearance. With simple yet elegant aesthetics, the Ultra Marine Blue model adds a vibrant splash of color to any space. Enjoy optimal airflow throughout your living or workspace with ease and convenience. Please note that this product does not include warranty details; kindly contact the seller directly for more information regarding after-sales support. Keyword optimization has been considered when writing the description but may still require further adjustment based on specific SEO requirements."
  },
  {
    "_id": "62da57fa863ba7c37a131622",
    "title": "Usha Swift 1400mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha
usha Bloom Primrose Sweep 1250mm Ceiling Fan (Golden and Cherry) offers great value for money, combining style and functionality at an affordable price point."
  },
  {
    "_id": "62da57fa863ba7c37a1315c7",
    "title": "Usha Bloom Magnolia Sweep 1250mm Ceiling Fan (White)",
    "description": "Product Name: Usha Bloom Magnolia Sweep 1250mm Ceiling Fan (White) Description: Introducing the Usha Bloom Magnolia Sweep 1250mm Ceiling Fan, a stylish and efficient addition to any room. This fan boasts a sleek white finish and elegant magnolia blades that complement modern decor while providing powerful air circulation. With a sweep of 1250mm, it covers large spaces with ease, ensuring consistent comfort throughout your home or office. Key Features: * Stylish design with a clean white finish and magnolia blades * Powerful 75-watt motor for effective air movement * Ideal for rooms up to 144 sq ft * High-speed operation ensures quick cooling * Low noise level for peaceful environment * Easy installation with included hardware * Energy-efficient performance saves electricity costs * Durable construction built for long-lasting use * Rust-resistant materials ensure longevity Specifications: * Brand: Usha * Model Number: Bloom Magnolia Sweep 1250mm * Colour: White * Blade Material: Aluminium * Motor Type: Single Phase Induction Motor * Controls: Pull Chain Regulator * Warranty: Please refer to manufacturer's warranty policy * Dimensions: Length - 1250mm, Height - 360mm, Width - 390mm * Weight: 8kg Note: Kindly check with the seller regarding warranty details before purchasing."
  },
  {
    "_id": "62da57fa863ba7c37a1315c9",
    "title": "Usha Striker Galaxy 1200mm Goodbye Dust Ceiling Fan (Corn Silk)",
    "description": "Product Name: Usha Striker Galaxy 1200mm Goodbye Dust Ceiling Fan (Corn Silk) Description: * Brand: Usha * Model: Striker Galaxy * Blade Sweep: 1200mm * Color: Corn Silk * Type: Ceiling Fan * Special Feature: Goodbye Dust technology for easy cleaning * Number of blades: 3 * Speed control: Yes, with regulator * Warranty: Not specified * Energy efficient motor ensures low power consumption. * Ribbed aluminium blades provide powerful air delivery and longer life. * Decorative and sturdy design suitable for all types of interiors. * Double ball bearing for smooth and noiseless operation. * Easy to install and maintain. * Comes with a stylish regulator for speed control. * Meets Indian safety standards (ISI marked). Keywords: Usha ceiling fan, Striker Galaxy, 1200mm blade sweep, corn silk color, goodbye dust technology, energy efficient, ribbed aluminum blades, double ball bearing, speed control regulator, ISI marked."
  },
  {
    "_id": "62da57fa863ba7c37a1315ce",
    "title": "Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Mist Metallic Green)",
    "description": "Product Name: Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Mist Metallic Green) Description: Introducing the Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan, now available in Mist Metallic Green. This fan is designed to deliver powerful air circulation while keeping your space dust-free. With its advanced Goodbye Dust technology, you can say goodbye to regular cleaning and maintenance hassles. Key Features: * Advanced Goodbye Dust Technology: Specially treated anti-static ABS blades reduce dust accumulation by up to 50%. * Powerful Air Circulation: Delivers high-speed cooling with an impressive air delivery of 230 cubic meters per minute. * Energy Efficient: Consumes only 75 watts of power for energy savings without compromising performance. * Long Life Span: High-quality motor ensures long life and durability. * Sweep Size: The large sweep size of 1200mm provides wide coverage and efficient cooling even in larger spaces. * Modern Design: Attractive mist metallic green color adds a touch of sophistication to any room decor. * Easy Installation: Comes with a user manual and all necessary hardware for easy installation. * Warranty: Backed by a limited warranty from Usha, ensuring customer satisfaction and reliability. This ceiling fan is suitable for both residential and commercial use, making it perfect for homes, offices, schools, hospitals, and other public spaces. Order yours today and enjoy cool, clean air throughout the year!"
  },
  {
    "_id": "62da57fa863ba7c37a1315db",
    "title": "Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Truffle Gloss)",
    "description": "Product Name: Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Truffle Gloss) Description: Introducing the Usha Bellissa 1200mm Goodbye Dust Ceiling Fan, now available in a stunning Truffle Gloss finish. This fan is designed to deliver powerful air circulation while keeping your space dust-free. With its impressive 1200mm sweep size, it provides efficient cooling for large rooms up to 250 square feet. Key Features: * Goodbye Dust technology: Unique anti-dust airflow mechanism prevents accumulation of dust particles, ensuring cleaner and healthier indoor environment. * Powerful motor: High-performance motor with double ball bearings ensures smooth operation and long-lasting durability. * Energy efficiency: Engineered to consume less power without compromising performance, making it an ideal choice for eco-conscious consumers. * Stunning design: Attractive truffle gloss finish adds sophistication and elegance to any room decor. * Wide sweep size: Covers larger areas effectively with its 1200mm blade span, providing optimal comfort during hot summer months. * Easy installation: Comes with all necessary mounting hardware and instructions, allowing easy do-it-yourself setup. * Smooth operation: Delivers silent yet effective air movement even at high speeds, maintaining peaceful ambiance in living spaces. Specifications: * Brand: Usha * Model name: Bellissa * Sweep Size: 1200mm * Color: Truffle Gloss * Material: Aluminum blades with ABS plastic body * Motor Type: Double Ball Bearing * Speed Control: Regulator compatible * Warranty: Please check manufacturer's website or contact their customer service for warranty details Note: Kindly refer to the user manual provided by the manufacturer for proper usage, maintenance tips, troubleshooting guidelines, and safety precautions before operating the product. Always follow local regulations regarding ceiling fan installations and consult professionals if needed."
  },
  {
    "_id": "62da57fa863ba7c37a1315fd",
    "title": "Usha Allure Deluxe 600mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Allure Deluxe 600mm Universal Ceiling Fan (Rich Brown) Description: * Introducing the Usha Allure Deluxe 600mm Universal Ceiling Fan, featuring a rich brown finish to add a touch of elegance to any room. * This fan is designed for universal fitting and can be installed in rooms with ceiling heights ranging from 2.5m to 3.5m. * It comes equipped with a powerful motor that delivers airflow up to 210 CMM, ensuring consistent cooling throughout your space. * The energy-efficient BEE 5-star rating ensures reduced electricity consumption without compromising performance. * With its stylish design and high functionality, it's perfect for both residential and commercial use. * The fan features three speed settings, allowing you to adjust the level of comfort according to your needs. * Its silent operation makes it ideal for bedrooms or study areas where quietness is essential. * Easy to install and maintain, the Usha Allure Deluxe Universal Ceiling Fan also includes a pull cord switch for added convenience. * Upgrade your home decor while enjoying efficient cooling with the Usha Allure Deluxe 600mm Universal Ceiling Fan in Rich Brown."
  },
  {
    "_id": "62da57fa863ba7c37a131600",
    "title": "Usha Aster Plus 1200mm Universal Ceiling Fan (Rich Ivory)",
    "description": "Product Name: Usha Aster Plus 1200mm Universal Ceiling Fan (Rich Ivory) Description: Introducing the Usha Aster Plus 1200mm Universal Ceiling Fan, featuring a rich ivory finish. This fan is designed to deliver powerful air circulation while adding an elegant touch to your room's decor. Its universal mounting system makes it compatible with both standard and sloped ceilings, making it suitable for installation in various spaces. Key Features: * Motor Type: Energy-efficient motor ensures low power consumption without compromising performance. * Blade Sweep: With a sweep of 1200mm, this ceiling fan provides wide coverage, ensuring uniform cooling throughout the room. * Rich Ivory Finish: The beautiful rich ivory color complements modern interiors effortlessly and adds sophistication to any space. * Universal Mounting System: Allows easy installation on both flat and angled surfaces, providing versatility for different applications. * High Speed: Delivers impressive high-speed performance, effectively circulating air even in larger rooms. * Durable Material: Constructed from premium materials to ensure long-lasting durability and resistance to wear and tear over time. * Easy Assembly: Comes with clear instructions for quick assembly, enabling users to install their new fans efficiently. * Quiet Operation: Designed for whisper-quiet operation, allowing you to enjoy peaceful surroundings without unwanted noise disturbances. * Suitable Room Size: Ideal for medium to large living areas, bedrooms, or office spaces up to 250 sq ft. Note: Kindly refer to the user manual provided with the product for specifications, dimensions, warranty details, and maintenance guidelines. This will assist you in optimally utilizing your newly purchased ceiling fan."
  },
  {
    "_id": "62da57fa863ba7c37a131602",
    "title": "Usha Neo Plus 1200mm Universal Ceiling Fan (Rich Ivory)",
    "description": "Product Name: Usha Neo Plus 1200mm Universal Ceiling Fan (Rich Ivory) Description: Introducing the Usha Neo Plus 1200mm Universal Ceiling Fan, featuring a rich ivory finish. This fan is designed to deliver powerful air circulation while adding a touch of elegance to your space. Its universal fit makes it suitable for any room size or ceiling height. With a sweep size of 1200mm, this fan ensures maximum coverage and efficient cooling. Key Features: * Rich Ivory Finish: Adds an elegant touch to your decor while complementing various interiors. * Powerful Air Delivery: Equipped with high-speed aluminum blades that ensure optimal air delivery even at low speeds. * Energy Efficient Motor: Designed for long-lasting performance and reduced energy consumption, helping you save on electricity bills. * Whisper Quiet Operation: Experience smooth operation without disturbances due to its aerodynamically designed motor and blade structure. * Wide Range Compatibility: Suitable for all mountings, including standard, sloped, or angled ceilings, making it perfect for installation in living rooms, bedrooms, kitchens, and more. * Easy Installation: Includes a user manual and required hardware for easy DIY installation, saving time and effort. Specifications: * Brand: Usha * Model: Neo Plus * Size: 1200mm * Color: Rich Ivory * Material: Aluminum Blades, Plastic Body * Control Type: Pull Chain Regulator * Number of Speeds: 3 * RPM: 350 (Low), 450 (Medium), 600 (High) * Voltage: 220V - 240V AC, Single Phase * Warranty: Please check with manufacturer or seller Note: Always refer to the manufacturer's website or consult with their customer support team regarding warranty details."
  },
  {
    "_id": "62da57fa863ba7c37a131606",
    "title": "Usha Xavia 1200mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Xavia 1200mm Universal Ceiling Fan (Rich Brown) Description: * The Usha Xavia ceiling fan is designed with a universal fit, making it suitable for any room in your home or office. * Its rich brown color adds warmth and sophistication to your decor, while the sleek design complements both traditional and modern spaces. * With a size of 1200mm, this fan provides efficient air circulation to keep you cool during hot summer days. * It features a high-speed motor that ensures powerful performance, along with an aerodynamic blade design for reduced noise and energy consumption. * The fan also includes a remote control for easy operation from anywhere in the room. * Additionally, the Usha Xavia comes with a two-year warranty for added peace of mind. Note: This product description focuses on providing relevant information about the Usha Xavia ceiling fan, including its features and benefits. However, it does not include SEO keywords or warranty details as requested."
  },
  {
    "_id": "62da57fa863ba7c37a131608",
    "title": "Usha Trump Plus 1200mm Universal Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Trump Plus 1200mm Universal Ceiling Fan (Rich White) Description: Introducing the Usha Trump Plus 1200mm Universal Ceiling Fan, featuring a rich white finish to complement any decor. This fan is designed for universal use and comes with a large 1200mm sweep size, providing efficient air circulation throughout your space. Its powerful motor ensures smooth operation at low noise levels, making it perfect for bedrooms, living rooms, or offices. Key Features: * Universal fit design suitable for all types of ceilings * Large 1200mm sweep size for optimal air circulation * Powerful motor ensuring quiet and smooth operation * Rich white finish adds elegance and style to any room * Ideal for both residential and commercial spaces Specifications: * Brand: Usha * Model Number: Trump Plus * Size: 1200mm * Color: Rich White * Material: Metal * Warranty: Please contact manufacturer for warranty details Note: We strive to provide accurate and up-to-date descriptions; however, we recommend checking the manufacturer's website for further specifications and warranties before purchasing."
  },
  {
    "_id": "62da57fa863ba7c37a13160a",
    "title": "Usha Racer 1200mm Universal Ceiling Fan (Rich Red)",
    "description": "Product Name: Usha Racer 1200mm Universal Ceiling Fan (Rich Red) Description: Introducing the Usha Racer 1200mm Universal Ceiling Fan, now available in a stunning Rich Red finish. This fan is designed to deliver powerful air circulation while adding a touch of elegance to your space. With its universal compatibility, it's perfect for any room in your home or office. Features: * Motor: Equipped with an efficient motor that ensures silent operation and long-lasting performance. * Blades: Made from high-quality aluminum material, the blades are designed for optimal air delivery and durability. * Size: The 1200mm blade sweep provides extensive coverage, making it ideal for large rooms up to 144 sq ft. * Design: Its aerodynamic design not only enhances its appearance but also improves its efficiency and reduces noise levels. * Colour: Add a pop of colour to your decor with the vibrant Rich Red finish, which complements both modern and traditional interiors. * Control: Includes a pull cord switch for easy control and convenience. * Warranty: Although warranty details may vary by region, rest assured knowing you have purchased a reliable and durable product from a reputable brand like Usha. Keywords: Usha Racer ceiling fan, red ceiling fan, 1200mm ceiling fan, universal ceiling fan, Usha fans, quiet ceiling fan, elegant ceiling fan, energy-efficient ceiling fan, durable ceiling fan, high-performance ceiling fan, Indian brand ceiling fan."
  },
  {
    "_id": "62da57fa863ba7c37a13160e",
    "title": "Usha Striker 1400mm Universal Ceiling Fan (Matte Brown)",
    "description": "Product Name: Usha Striker 1400mm Universal Ceiling Fan (Matte Brown) Description: Introducing the Usha Striker 1400mm Universal Ceiling Fan, featuring a sleek matte brown finish. This fan is designed to deliver powerful air circulation while adding a touch of elegance to your space. With its universal mounting system, it's suitable for both standard and sloped ceilings up to 30 degrees. Key Features: * Size: 1400mm (56 inches) sweep diameter provides efficient cooling for large rooms * Finish: Matte brown color adds sophistication and complements any decor * Motor Type: High-performance motor ensures whisper-quiet operation and long lifespan * Blade Material: Durable plastic blades resist warping and ensure consistent performance over time * Included Accessories: Comes with a ball point fitting for easy installation and height adjustment * Warranty: Please refer to the manufacturer for warranty details Specifications: * Voltage: AC 220-240V * Power Consumption: 78W * Speed Control: Regulator compatible * RPM Range: 300-390RPM * Air Delivery: Up to 230 cubic meters per minute * Weight: Approximately 8kg This ceiling fan is perfect for living rooms, bedrooms, or other large spaces where effective cooling is required. Its stylish design makes it an excellent choice for modern homes, offices, or commercial establishments looking for high-quality ventilation solutions. Order now and experience unmatched comfort and style! SEO Keywords: Usha Striker ceiling fan, matte brown ceiling fan, 1400mm ceiling fan, universal ceiling fan, durable plastic blades, quiet operation, energy-efficient"
  },
  {
    "_id": "62da57fa863ba7c37a131615",
    "title": "Usha Striker 1200mm Universal Ceiling Fan (Matte Brown)",
    "description": "Product Name: Usha Striker 1200mm Universal Ceiling Fan (Matte Brown) Description: * Product Dimensions: Diameter - 1200mm, Height - 350mm * Material: High-quality plastic and metal * Finish: Matte brown * Motor Type: Energy-efficient AC motor with double ball bearing for smooth operation * Blades: 3 durable PVC blades with aerodynamic design for maximum air delivery * Speed Control: Regulator included for variable speed control * Warranty: N/A * Additional Features: Rust-resistant coating, low noise during operation, suitable for all room sizes. This Usha Striker 1200mm Universal Ceiling Fan is designed to deliver powerful cooling performance while maintaining an energy-efficient operation. Its matte brown finish adds style and elegance to any room decor. With its high-quality construction using robust materials like plastic and metal, the fan promises durability and longevity. The ceiling fan features an energy-efficient AC motor with double ball bearings that ensure smooth and quiet operation. It comes equipped with three durable PVC blades having an aerodynamic design that maximizes air delivery, providing efficient cooling throughout the space. For added convenience, the regulator allows you to adjust the fan's speed according to your preference. Additionally, it boasts rust-resistant coatings ensuring long-lasting use even in humid conditions. This versatile ceiling fan is ideal for rooms of various sizes, making it perfect for both residential and commercial spaces."
  },
]

# Preprocess and encode the descriptions
descriptions = [product['description'] for product in products]
encoded_descriptions = model.encode(descriptions)

# Function to recommend a product based on a query with feedback loop
def recommend_product(query, feedback=False, excluded_indices=[]):
    # Preprocess and encode the query
    query_embedding = model.encode([query])

    # Compute similarities
    similarities = cosine_similarity(query_embedding, encoded_descriptions).flatten()

    # Sort the indices of similarities in descending order
    sorted_indices = similarities.argsort()[::-1]

    # Recommend the top product that is not in the excluded_indices
    for index in sorted_indices:
        if index not in excluded_indices:
            recommended_index = index
            break

    # If feedback is true, call the function again with updated excluded indices
    if feedback:
        excluded_indices.append(recommended_index)
        return recommend_product(query, feedback=False, excluded_indices=excluded_indices)

    # Return the recommended product
    return products[recommended_index]

# Usage
query = "gold fan 1200mm"
recommended_product = recommend_product(query)
print(f"Recommended Product: {recommended_product['title']}")

# If the recommendation is not satisfactory
# Out:
# Recommended Product: Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Frosty Grey)

# %%
feedback = True  # This would typically be input from the user
if feedback:
    second_recommendation = recommend_product(query, feedback, [products.index(recommended_product)])
    print(f"Next Recommended Product: {second_recommendation['title']}")
# Out:
# Next Recommended Product: Usha Striker Plus 1200mm Energy Saving Ceiling Fan (White)

# %% [markdown]
# **TRY3**

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Your dataset
products = [

  {
    "_id": "62da57fa863ba7c37a1315cf",
    "title": "Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Frosty Grey)",
    "description": "Product Name: Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Frosty Grey) Description: Introducing the Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan, featuring an elegant frosty grey finish. This fan is designed to keep you cool while also maintaining a clean home environment with its unique Goodbye Dust technology. Its 1200mm sweep size ensures powerful air delivery for effective cooling in large rooms up to 180 sq ft. Key Features: * Frosty Grey Finish: Adds a modern touch to your decor while complementing various color schemes. * Goodbye Dust Technology: Specially treated blades repel dust accumulation, making cleaning easier and less frequent. * Powerful Air Delivery: With a 1200mm sweep size, enjoy efficient cooling even in larger spaces. * High-Performance Motor: Ensures smooth operation and long lifespan, delivering reliable performance year after year. * Ribbed Aluminium Blades: Designed for optimal balance between style and functionality. * Energy Efficient: Consumes low power without compromising on performance or durability. * Easy Installation: Compatible with standard ceiling mounts, allowing easy installation for DIY enthusiasts. * Wide Range of Speeds: Offers multiple speed settings, enabling customized comfort based on personal preferences. This Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan combines sleek design, innovative features, and dependable performance. Experience enhanced air circulation and improved indoor air quality today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315da",
    "title": "Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold)",
    "description": "Product Name: Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold) Description: * Introducing the Usha Bellissa 1200mm Goodbye Dust Ceiling Fan, featuring an innovative design that helps reduce dust accumulation. * This fan boasts a sleek bright gold finish that adds a touch of elegance to any room decor. * With a sweep size of 1200mm, it provides efficient air circulation for large spaces up to 250 sq ft. * Its powerful motor delivers silent yet effective cooling performance with high-speed operation of 370 RPM. * Equipped with a remote control, you can easily adjust the fan speed from the comfort of your seat. * The fan also includes features such as sleep mode, timer function, and boost mode for added convenience. * Energy efficient, the Usha Bellissa ceiling fan is designed to consume less power while delivering superior performance. * Maintenance free, its goodbye dust technology ensures easy cleaning without the use of water or harsh chemicals. * Installation is simple with included mounting hardware and instructions. * Experience unmatched style, performance, and ease of use with the Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold)."
  },
  {
    "_id": "62da57fa863ba7c37a1315dd",
    "title": "Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan",
    "description": "Product Name: Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan Description: Introducing the Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan, designed to inspire your child's imagination while keeping them cool. This fan is perfect for children who love Barbie dolls and dream of becoming anything they want to be. With its stylish and colorful design, it will add a touch of fun and excitement to any room. The fan features a blade span of 1200mm, providing efficient air circulation to keep your child comfortable even during hot summer days. It has a high-speed motor that ensures quiet operation, so it won't disturb your child's sleep or playtime. The fan also comes with a remote control, allowing you to easily adjust the speed and mode from anywhere in the room. Safety is a top priority with this ceiling fan. It is equipped with a sturdy construction and a stable mounting system to prevent accidents. The blades are made of durable plastic material, ensuring long-lasting use. Plus, the fan is easy to install, making it convenient for parents. This ceiling fan is not only functional but also decorative. Its vibrant colors and Barbie-themed design make it an attractive addition to your child's bedroom or playroom. It is suitable for kids aged three years old and above. In summary, the Usha Barbie You Can Be Anything Kids 1200mm Ceiling Fan is a fantastic choice if you want to combine style, safety, and functionality in one product. Order now and let your child's dreams take flight!"
  },
  {
    "_id": "62da57fa863ba7c37a1315e1",
    "title": "Usha Striker Plus 1200mm Energy Saving Ceiling Fan (White)",
    "description": "Product Name: Usha Striker Plus 1200mm Energy Saving Ceiling Fan (White) Description: Introducing the Usha Striker Plus 1200mm Energy Saving Ceiling Fan, now available in a sleek white finish. This fan is designed to deliver powerful airflow while keeping energy consumption low, making it an ideal choice for any room in your home or office. Key Features: * Energy-saving motor: The fan's high-performance motor consumes less power compared to conventional fans, helping you save on electricity bills without compromising on comfort. * Large blade sweep size: With a blade sweep of 1200mm, this ceiling fan provides wide coverage and ensures efficient cooling throughout the room. * Durable build: Constructed with high-quality materials, this fan boasts long-lasting performance and durability, ensuring reliable operation year after year. * Whisper-quiet operation: Equipped with aerodynamically designed blades, this fan operates silently, providing uninterrupted relaxation and productivity. * Easy installation: Compatible with both standard and sloped ceilings, this fan features hassle-free mounting options for easy setup. * Attractive design: Featuring elegant curves and a clean white finish, this fan complements various decor styles and adds a touch of sophistication to any space. Specifications: * Brand: Usha * Model name: Striker Plus * Blade span: 1200mm * Motor type: Energy saving * Colour: White * Warranty: Please check with the manufacturer for warranty details Note: Always refer to the user manual provided by the manufacturer for proper usage instructions, maintenance tips, and safety guidelines."
  },
  {
    "_id": "62da57fa863ba7c37a1315e5",
    "title": "Usha Energia ISI 1400mm Energy Saving Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Energia ISI 1400mm Energy Saving Ceiling Fan (Rich White) Description: Introducing the Usha Energia ISI 1400mm Energy Saving Ceiling Fan, now available in Rich White. This fan is designed to deliver high-quality performance while helping you save energy and money on your electricity bills. With its impressive air delivery of 230 CMM, this fan ensures efficient cooling even in large rooms up to 160 sq ft. The Usha Energia ceiling fan features an aerodynamic design with swept aluminum blades that are engineered for optimal airflow and reduced power consumption. It also comes equipped with a powerful motor that operates quietly, ensuring comfortable and peaceful indoor environments. This fan boasts a sleek and modern design, making it a stylish addition to any room décor. Its premium finish adds a touch of elegance and sophistication, complementing both traditional and contemporary spaces. Furthermore, the fan's sturdy construction ensures long-lasting durability, providing reliable operation year after year. Key Features: * ISI certified for quality assurance * Aerodynamically designed swept aluminum blades * High air delivery of 230 CMM * Powerful motor for quiet and efficient operation * Modern and elegant design in Rich White color * Suitable for large rooms up to 160 sq ft * Long-lasting durability Whether you're looking to upgrade your home or office space, the Usha Energia ISI 1400mm Energy Saving Ceiling Fan is an excellent choice. Experience superior comfort, style, and savings today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315ea",
    "title": "Usha Nabila 1200mm Energy Saving Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Nabila 1200mm Energy Saving Ceiling Fan (Rich Brown) Description: Introducing the Usha Nabila 1200mm Energy Saving Ceiling Fan, featuring a rich brown finish to complement any home decor. This fan is designed with energy efficiency in mind, using advanced technology to reduce power consumption without sacrificing performance. With a sweep size of 1200mm, it provides efficient air circulation for medium-sized rooms. Key Features: * Rich brown color adds warmth and style to your room * Advanced aerodynamic design ensures optimal air delivery while reducing noise levels * High-quality motor delivers powerful and consistent airflow * Specially treated blades prevent rust and corrosion over time * Energy saving mode reduces power usage by up to 35% compared to traditional fans * Includes a remote control for easy operation from anywhere in the room * Durable build quality ensures long-lasting use and minimal maintenance requirements * Suitable for ceiling heights between 2.8m - 3.4m * Easy installation process with all necessary hardware included Specifications: * Brand: Usha * Model: Nabila * Color: Rich Brown * Blade Material: Aluminum * Motor Type: Single phase induction motor * Speed Control: Remote controlled * Warranty: Contact manufacturer for details This Usha Nabila 1200mm Energy Saving Ceiling Fan is perfect for those looking to upgrade their existing fan or add a stylish yet functional piece to their space. Its energy-saving features make it an environmentally friendly choice, while its durable build and warranty ensure peace of mind. Order yours today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315f4",
    "title": "Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White) Product Description: * Introduction: Introduce the product, its brand name \"Usha\" which is known for quality fans, and highlight its key feature - universal fitting. Mention the color option available - Rich white. * Size & Dimensions: Specify the size of the fan to be 1400mm, suitable for medium-large sized rooms. Mention the dimensions of the fan to give an idea about its space requirement. * Materials Used: List down the materials used in constructing the fan such as high-quality plastic and metal, ensuring durability and long life. * Motor Type: Highlight the powerful motor with efficient air delivery, providing excellent cooling performance even at low speeds. Also, mention the noise level to ensure quiet operation. * Blade Design: Describe the number and design of blades, including their aerodynamic shape for optimal airflow and energy efficiency. Mention any additional features like rust-free or anti-dust properties. * Control Options: Explain the control options available, such as pull cords, wall controls or remote control, making it convenient for users to operate from anywhere in the room. * Installation: Provide details regarding installation process, compatibility with different ceiling types, and if professional installation is recommended. * Additional Features: If applicable, include other notable features such as summer-winter function, LED light kit, oscillating mechanism etc. * Conclusion: Summarize the main benefits and selling points of the Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White), emphasizing on its versatility and functionality. Note: SEO Keywords are not included in this format but suggested words could be 'Usha', 'Ceiling Fan', 'Universal Fitting', 'Rich White', 'Powerful Motor', 'Aerodynamic Blades' etc."
  },
  {
    "_id": "62da57fa863ba7c37a1315c3",
    "title": "Usha Bloom Primrose Sweep 1250mm Ceiling Fan (White)",
Order yours today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315d7",
    "title": "Usha Elsa 1200mm Goodbye Dust Ceiling Fan (Copper Gold)",
    "description": "Product Name: Usha Elsa 1200mm Goodbye Dust Ceiling Fan (Copper Gold) Description: Introducing the Usha Elsa 1200mm Goodbye Dust Ceiling Fan, now available in an elegant Copper Gold finish. This fan is designed to keep your space cool while keeping dust away, making it perfect for those who suffer from allergies or asthma. With its powerful motor, the Usha Elsa provides efficient air circulation, ensuring that every corner of the room stays comfortable even during the hottest summer days. The Goodbye Dust feature ensures that the blades are specially treated with a coating that repels dust, reducing the frequency of cleaning required. Its 1200mm sweep diameter makes it suitable for medium-sized rooms, providing optimal coverage and performance. Additionally, the fan's sleek design and high-quality construction make it a stylish addition to any home or office decor. It also comes with a remote control, allowing you to adjust the speed settings and switch off the fan without having to get up from your seat. Key Features: * Powerful motor for efficient air circulation * Specialized Goodbye Dust treatment for reduced cleaning frequency * Suitable for medium-sized rooms with a 1200mm sweep diameter * Sleek design and high-quality construction * Remote control included for added convenience * Available in an attractive Copper Gold finish."
  },
  {
    "_id": "62da57fa863ba7c37a131613",
    "title": "Usha Striker 900mm Universal Ceiling Fan (Rich Ivory)",
    "description": "Product Name: Usha Striker 900mm Universal Ceiling Fan (Rich Ivory) Description: Introducing the Usha Striker 900mm Universal Ceiling Fan, featuring a rich ivory finish that adds elegance to any room. This fan is designed for universal use, making it suitable for both residential and commercial spaces. With a size of 900mm, it provides efficient air circulation, ensuring consistent comfort throughout your space. Key Features: * Rich ivory color for an elegant look * Suitable for both indoor and outdoor use * High-performance motor for powerful air delivery * Energy-efficient operation with low noise levels * Easy installation process * Durable build quality for long-lasting performance Specifications: * Size: 900mm * Finish: Rich Ivory * Material: Metal * Motor Type: High Performance * Warranty: N/A This ceiling fan from Usha is perfect for those looking for reliable and stylish cooling solution. Its sleek design, combined with its powerful performance, makes it an excellent choice for large rooms or areas where effective air circulation is essential. Whether you're using it at home or in a commercial setting, the Usha Striker 900mm Universal Ceiling Fan will not disappoint. Order yours today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315f3",
    "title": "Usha Striker Millennium 1200mm Universal Ceiling Fan (Ultra Marine Blue)",
    "description": "Product Name: Usha Striker Millennium 1200mm Universal Ceiling Fan (Ultra Marine Blue) Description: Introducing the Usha Striker Millennium 1200mm Universal Ceiling Fan, featuring an Ultra Marine Blue color finish. This fan is designed to deliver powerful air circulation while adding a touch of style to your room decor. Its universal mounting system makes it suitable for both standard and sloped ceilings. Key Features: * Size: 1200mm (48 inches) sweep diameter, ideal for medium-sized rooms up to 150 sq ft. * Motor Type: High-performance motor with superior wind flow technology ensures efficient cooling even at low speeds. * Blade Material: Durable, high-quality plastic blades offer long-lasting performance and require minimal maintenance. * Color: Attractive Ultra Marine Blue finish complements modern interiors beautifully. * Mounting System: Includes a universal mounting bracket compatible with flat and angled surfaces, making installation easy and versatile. * Energy Efficiency: Designed for energy efficiency without compromising its cooling capabilities. * Noise Level: Smooth operation with reduced noise levels provides maximum comfort. This ceiling fan from Usha's Striker series offers excellent value for money due to its robust build quality and stylish appearance. With simple yet elegant aesthetics, the Ultra Marine Blue model adds a vibrant splash of color to any space. Enjoy optimal airflow throughout your living or workspace with ease and convenience. Please note that this product does not include warranty details; kindly contact the seller directly for more information regarding after-sales support. Keyword optimization has been considered when writing the description but may still require further adjustment based on specific SEO requirements."
  },
  {
    "_id": "62da57fa863ba7c37a131622",
    "title": "Usha Swift 1400mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Swift 1400mm Universal Ceiling Fan (Rich Brown) Description: Introducing the Usha
enience. * Suitability: Ideal for rooms up to 150 sq ft, perfect for living areas, bedrooms, or offices. * Warranty: Contact manufacturer for warranty details. SEO Keywords: Usha Sonata Ceiling Fan, Rich White Finish, Powerful Air Circulation, Energy Efficient, Modern Style, Generous Blade Sweep, Durable Motor, Three Sturdy Blades, Pull Cord Switch, Room Cooling Solution, High Performance, Low Noise Operation, Residential & Commercial Use."
  },
  {
    "_id": "62da57fa863ba7c37a131620",
    "title": "Usha Sonata 1200mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Sonata 1200mm Universal Ceiling Fan (Rich Brown) Description: Introducing the Usha Sonata 1200mm Universal Ceiling Fan, now available in a rich brown finish to complement your home decor. This fan is designed for universal use, making it suitable for any room in your house. With its impressive 1200mm sweep size, the Usha Sonata provides efficient air circulation to keep you cool during hot summer months. Its high-speed performance of up to 380 RPM ensures quick cooling, while its low-speed setting helps maintain comfortable temperatures all year round. The fan features an aerodynamic design with swept back aluminum blades that reduce aircutting noise, providing a peaceful environment for sleeping or working. It also has a double ball bearing mechanism for long-lasting durability and silent operation. Additionally, the Usha Sonata comes with a two-way adjustable mounting system, allowing for easy installation on both standard and sloped ceilings. Key Features: * Suitable for all rooms * 1200mm sweep size for efficient air circulation * High-speed performance of up to 380 RPM * Low-noise operation due to aerodynamic design * Double ball bearing mechanism for longevity * Two-way adjustable mounting system for versatile installation * Rich brown color adds elegance and style to any space This Usha ceiling fan offers excellent value for money and promises reliable performance backed by the trusted reputation of Usha brand. Upgrade your living space with the modern design and powerful functionality of the Usha Sonata 1200mm Universal Ceiling Fan (Rich Brown)."
  },
  {
    "_id": "62da57fa863ba7c37a1315c4",
    "title": "Usha Bloom Primrose Sweep 1250mm Ceiling Fan (Golden And Cherry)",
    "description": "Product Name: Usha Bloom Primrose Sweep 1250mm Ceiling Fan (Golden and Cherry) Product Description: * Type: Ceiling fan * Brand: Usha * Model: Bloom Primrose * Blade span: 1250mm (49.2 inches) * Finish: Golden and Cherry * Materials: High-quality metal and wood * Controls: Pull cord regulation * Warranty: Contact manufacturer for details * Special features: Energy-efficient motor, stylish design, quiet operation * Applicable room size: Medium to large rooms * Voltage: 230V AC, 50Hz * Weight: 7kg * Additional accessories included: None * Other features: Decorative and functional, provides smooth airflow, easy installation This ceiling fan from Usha is an excellent choice for those who want a decorative yet efficient cooling solution for their homes or offices. With its elegant golden and cherry finish, the fan adds a touch of sophistication to any space while providing powerful air circulation. The high-quality materials used in construction ensure durability and long-lasting performance. The energy-efficient motor ensures low power consumption without compromising on the fan's efficiency. It comes with pull cord controls for ease of use, making it simple to adjust the speed according to your comfort level. The fan has been designed to operate quietly, ensuring minimal noise disturbance. With a blade sweep of 1250mm, the Usha Bloom Primrose fan is suitable for medium to large-sized rooms. Its stylish design complements both modern and traditional decors, making it a versatile addition to any space. Installation is straightforward and hassle-free, thanks to clear instructions provided by the manufacturer. Overall, the Usha Bloom Primrose Sweep 1250mm Ceiling Fan (Golden and Cherry) offers great value for money, combining style and functionality at an affordable price point."
  },
  {
    "_id": "62da57fa863ba7c37a1315c7",
    "title": "Usha Bloom Magnolia Sweep 1250mm Ceiling Fan (White)",
Usha Bellissa 1200mm Goodbye Dust Ceiling Fan, now available in a stunning Truffle Gloss finish. This fan is designed to deliver powerful air circulation while keeping your space dust-free. With its impressive 1200mm sweep size, it provides efficient cooling for large rooms up to 250 square feet. Key Features: * Goodbye Dust technology: Unique anti-dust airflow mechanism prevents accumulation of dust particles, ensuring cleaner and healthier indoor environment. * Powerful motor: High-performance motor with double ball bearings ensures smooth operation and long-lasting durability. * Energy efficiency: Engineered to consume less power without compromising performance, making it an ideal choice for eco-conscious consumers. * Stunning design: Attractive truffle gloss finish adds sophistication and elegance to any room decor. * Wide sweep size: Covers larger areas effectively with its 1200mm blade span, providing optimal comfort during hot summer months. * Easy installation: Comes with all necessary mounting hardware and instructions, allowing easy do-it-yourself setup. * Smooth operation: Delivers silent yet effective air movement even at high speeds, maintaining peaceful ambiance in living spaces. Specifications: * Brand: Usha * Model name: Bellissa * Sweep Size: 1200mm * Color: Truffle Gloss * Material: Aluminum blades with ABS plastic body * Motor Type: Double Ball Bearing * Speed Control: Regulator compatible * Warranty: Please check manufacturer's website or contact their customer service for warranty details Note: Kindly refer to the user manual provided by the manufacturer for proper usage, maintenance tips, troubleshooting guidelines, and safety precautions before operating the product. Always follow local regulations regarding ceiling fan installations and consult professionals if needed."
  },
  {
    "_id": "62da57fa863ba7c37a1315fd",
    "title": "Usha Allure Deluxe 600mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Allure Deluxe 600mm Universal Ceiling Fan (Rich Brown) Description: * Introducing the Usha Allure Deluxe 600mm Universal Ceiling Fan, featuring a rich brown finish to add a touch of elegance to any room. * This fan is designed for universal fitting and can be installed in rooms with ceiling heights ranging from 2.5m to 3.5m. * It comes equipped with a powerful motor that delivers airflow up to 210 CMM, ensuring consistent cooling throughout your space. * The energy-efficient BEE 5-star rating ensures reduced electricity consumption without compromising performance. * With its stylish design and high functionality, it's perfect for both residential and commercial use. * The fan features three speed settings, allowing you to adjust the level of comfort according to your needs. * Its silent operation makes it ideal for bedrooms or study areas where quietness is essential. * Easy to install and maintain, the Usha Allure Deluxe Universal Ceiling Fan also includes a pull cord switch for added convenience. * Upgrade your home decor while enjoying efficient cooling with the Usha Allure Deluxe 600mm Universal Ceiling Fan in Rich Brown."
  },
  {
    "_id": "62da57fa863ba7c37a131600",
    "title": "Usha Aster Plus 1200mm Universal Ceiling Fan (Rich Ivory)",
    "description": "Product Name: Usha Aster Plus 1200mm Universal Ceiling Fan (Rich Ivory) Description: Introducing the Usha Aster Plus 1200mm Universal Ceiling Fan, featuring a rich ivory finish. This fan is designed to deliver powerful air circulation while adding an elegant touch to your room's decor. Its universal mounting system makes it compatible with both standard and sloped ceilings, making it suitable for installation in various spaces. Key Features: * Motor Type: Energy-efficient motor ensures low power consumption without compromising performance. * Blade Sweep: With a sweep of 1200mm, this ceiling fan provides wide coverage, ensuring uniform cooling throughout the room. * Rich Ivory Finish: The beautiful rich ivory color complements modern interiors effortlessly and adds sophistication to any space. * Universal Mounting System: Allows easy installation on both flat and angled surfaces, providing versatility for different applications. * High Speed: Delivers impressive high-speed performance, effectively circulating air even in larger rooms. * Durable Material: Constructed from premium materials to ensure long-lasting durability and resistance to wear and tear over time. * Easy Assembly: Comes with clear instructions for quick assembly, enabling users to install their new fans efficiently. * Quiet Operation: Designed for whisper-quiet operation, allowing you to enjoy peaceful surroundings without unwanted noise disturbances. * Suitable Room Size: Ideal for medium to large living areas, bedrooms, or office spaces up to 250 sq ft. Note: Kindly refer to the user manual provided with the product for specifications, dimensions, warranty details, and maintenance guidelines. This will assist you in optimally utilizing your newly purchased ceiling fan."
  },
  {
    "_id": "62da57fa863ba7c37a131602",
    "title": "Usha Neo Plus 1200mm Universal Ceiling Fan (Rich Ivory)",
    "description": "Product Name: Usha Neo Plus 1200mm Universal Ceiling Fan (Rich Ivory) Description: Introducing the Usha Neo Plus 1200mm Universal Ceiling Fan, featuring a rich ivory finish. This fan is designed to deliver powerful air circulation while adding a touch of elegance to your space. Its universal fit makes it suitable for any room size or ceiling height. With a sweep size of 1200mm, this fan ensures maximum coverage and efficient cooling. Key Features: * Rich Ivory Finish: Adds an elegant touch to your decor while complementing various interiors. * Powerful Air Delivery: Equipped with high-speed aluminum blades that ensure optimal air delivery even at low speeds. * Energy Efficient Motor: Designed for long-lasting performance and reduced energy consumption, helping you save on electricity bills. * Whisper Quiet Operation: Experience smooth operation without disturbances due to its aerodynamically designed motor and blade structure. * Wide Range Compatibility: Suitable for all mountings, including standard, sloped, or angled ceilings, making it perfect for installation in living rooms, bedrooms, kitchens, and more. * Easy Installation: Includes a user manual and required hardware for easy DIY installation, saving time and effort. Specifications: * Brand: Usha * Model: Neo Plus * Size: 1200mm * Color: Rich Ivory * Material: Aluminum Blades, Plastic Body * Control Type: Pull Chain Regulator * Number of Speeds: 3 * RPM: 350 (Low), 450 (Medium), 600 (High) * Voltage: 220V - 240V AC, Single Phase * Warranty: Please check with manufacturer or seller Note: Always refer to the manufacturer's website or consult with their customer support team regarding warranty details."
  },
  {
    "_id": "62da57fa863ba7c37a131606",
    "title": "Usha Xavia 1200mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Xavia 1200mm Universal Ceiling Fan (Rich Brown) Description: * The Usha Xavia ceiling fan is designed with a universal fit, making it suitable for any room in your home or office. * Its rich brown color adds warmth and sophistication to your decor, while the sleek design complements both traditional and modern spaces. * With a size of 1200mm, this fan provides efficient air circulation to keep you cool during hot summer days. * It features a high-speed motor that ensures powerful performance, along with an aerodynamic blade design for reduced noise and energy consumption. * The fan also includes a remote control for easy operation from anywhere in the room. * Additionally, the Usha Xavia comes with a two-year warranty for added peace of mind. Note: This product description focuses on providing relevant information about the Usha Xavia ceiling fan, including its features and benefits. However, it does not include SEO keywords or warranty details as requested."
  },
  {
    "_id": "62da57fa863ba7c37a131608",
    "title": "Usha Trump Plus 1200mm Universal Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Trump Plus 1200mm Universal Ceiling Fan (Rich White) Description: Introducing the Usha Trump Plus 1200mm Universal Ceiling Fan, featuring a rich white finish to complement any decor. This fan is designed for universal use and comes with a large 1200mm sweep size, providing efficient air circulation throughout your space. Its powerful motor ensures smooth operation at low noise levels, making it perfect for bedrooms, living rooms, or offices. Key Features: * Universal fit design suitable for all types of ceilings * Large 1200mm sweep size for optimal air circulation * Powerful motor ensuring quiet and smooth operation * Rich white finish adds elegance and style to any room * Ideal for both residential and commercial spaces Specifications: * Brand: Usha * Model Number: Trump Plus * Size: 1200mm * Color: Rich White * Material: Metal * Warranty: Please contact manufacturer for warranty details Note: We strive to provide accurate and up-to-date descriptions; however, we recommend checking the manufacturer's website for further specifications and warranties before purchasing."
  },
  {
    "_id": "62da57fa863ba7c37a13160a",
    "title": "Usha Racer 1200mm Universal Ceiling Fan (Rich Red)",
    "description": "Product Name: Usha Racer 1200mm Universal Ceiling Fan (Rich Red) Description: Introducing the Usha Racer 1200mm Universal Ceiling Fan, now available in a stunning Rich Red finish. This fan is designed to deliver powerful air circulation while adding a touch of elegance to your space. With its universal compatibility, it's perfect for any room in your home or office. Features: * Motor: Equipped with an efficient motor that ensures silent operation and long-lasting performance. * Blades: Made from high-quality aluminum material, the blades are designed for optimal air delivery and durability. * Size: The 1200mm blade sweep provides extensive coverage, making it ideal for large rooms up to 144 sq ft. * Design: Its aerodynamic design not only enhances its appearance but also improves its efficiency and reduces noise levels. * Colour: Add a pop of colour to your decor with the vibrant Rich Red finish, which complements both modern and traditional interiors. * Control: Includes a pull cord switch for easy control and convenience. * Warranty: Although warranty details may vary by region, rest assured knowing you have purchased a reliable and durable product from a reputable brand like Usha. Keywords: Usha Racer ceiling fan, red ceiling fan, 1200mm ceiling fan, universal ceiling fan, Usha fans, quiet ceiling fan, elegant ceiling fan, energy-efficient ceiling fan, durable ceiling fan, high-performance ceiling fan, Indian brand ceiling fan."
  },
  {
    "_id": "62da57fa863ba7c37a13160e",
    "title": "Usha Striker 1400mm Universal Ceiling Fan (Matte Brown)",
    "description": "Product Name: Usha Striker 1400mm Universal Ceiling Fan (Matte Brown) Description: Introducing the Usha Striker 1400mm Universal Ceiling Fan, featuring a sleek matte brown finish. This fan is designed to deliver powerful air circulation while adding a touch of elegance to your space. With its universal mounting system, it's suitable for both standard and sloped ceilings up to 30 degrees. Key Features: * Size: 1400mm (56 inches) sweep diameter provides efficient cooling for large rooms * Finish: Matte brown color adds sophistication and complements any decor * Motor Type: High-performance motor ensures whisper-quiet operation and long lifespan * Blade Material: Durable plastic blades resist warping and ensure consistent performance over time * Included Accessories: Comes with a ball point fitting for easy installation and height adjustment * Warranty: Please refer to the manufacturer for warranty details Specifications: * Voltage: AC 220-240V * Power Consumption: 78W * Speed Control: Regulator compatible * RPM Range: 300-390RPM * Air Delivery: Up to 230 cubic meters per minute * Weight: Approximately 8kg This ceiling fan is perfect for living rooms, bedrooms, or other large spaces where effective cooling is required. Its stylish design makes it an excellent choice for modern homes, offices, or commercial establishments looking for high-quality ventilation solutions. Order now and experience unmatched comfort and style! SEO Keywords: Usha Striker ceiling fan, matte brown ceiling fan, 1400mm ceiling fan, universal ceiling fan, durable plastic blades, quiet operation, energy-efficient"
  },
  {
    "_id": "62da57fa863ba7c37a131615",
    "title": "Usha Striker 1200mm Universal Ceiling Fan (Matte Brown)",
    "description": "Product Name: Usha Striker 1200mm Universal Ceiling Fan (Matte Brown) Description: * Product Dimensions: Diameter - 1200mm, Height - 350mm * Material: High-quality plastic and metal * Finish: Matte brown * Motor Type: Energy-efficient AC motor with double ball bearing for smooth operation * Blades: 3 durable PVC blades with aerodynamic design for maximum air delivery * Speed Control: Regulator included for variable speed control * Warranty: N/A * Additional Features: Rust-resistant coating, low noise during operation, suitable for all room sizes. This Usha Striker 1200mm Universal Ceiling Fan is designed to deliver powerful cooling performance while maintaining an energy-efficient operation. Its matte brown finish adds style and elegance to any room decor. With its high-quality construction using robust materials like plastic and metal, the fan promises durability and longevity. The ceiling fan features an energy-efficient AC motor with double ball bearings that ensure smooth and quiet operation. It comes equipped with three durable PVC blades having an aerodynamic design that maximizes air delivery, providing efficient cooling throughout the space. For added convenience, the regulator allows you to adjust the fan's speed according to your preference. Additionally, it boasts rust-resistant coatings ensuring long-lasting use even in humid conditions. This versatile ceiling fan is ideal for rooms of various sizes, making it perfect for both residential and commercial spaces."
  },]

# Preprocess and encode the descriptions
descriptions = [product['description'] for product in products]
encoded_descriptions = model.encode(descriptions)

# Function to recommend products based on a query with feedback loop
def recommend_product(query, excluded_indices=[]):
    # Preprocess and encode the query
    query_embedding = model.encode([query])

    # Compute similarities
    similarities = cosine_similarity(query_embedding, encoded_descriptions).flatten()

    # Sort the indices of similarities in descending order
    sorted_indices = similarities.argsort()[::-1]

    # Iterate over sorted indices and yield product recommendations
    for index in sorted_indices:
        if index not in excluded_indices:
            yield products[index]

# Function to handle the interactive recommendation process
def interactive_recommendation():
    query = input("Please enter your query (e.g., 'gold fan 1200mm'): ")
    excluded_indices = []
    recommender = recommend_product(query, excluded_indices)

    for recommended_product in recommender:
        # Show the recommendation to the user
        print(f"Recommended Product: {recommended_product['title']}")
        feedback = input("Is this recommendation satisfactory? (True/False): ").strip()

        if feedback.lower() == 'true':
            print("Recommendation accepted. Thank you!")
            break
        else:
            excluded_indices.append(products.index(recommended_product))
            print("Let's try another recommendation...\n")

# Run the interactive recommendation
interactive_recommendation()
# Out:
# Please enter your query (e.g., 'gold fan 1200mm'): ushe celling fan
# Recommended Product: Usha Striker 1200mm Universal Ceiling Fan (Matte Brown)
# Is this recommendation satisfactory? (True/False): True
# Recommendation accepted. Thank you!

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Your dataset
products = [

  {
    "_id": "62da57fa863ba7c37a1315cf",
    "title": "Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Frosty Grey)",
    "description": "Product Name: Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan (Frosty Grey) Description: Introducing the Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan, featuring an elegant frosty grey finish. This fan is designed to keep you cool while also maintaining a clean home environment with its unique Goodbye Dust technology. Its 1200mm sweep size ensures powerful air delivery for effective cooling in large rooms up to 180 sq ft. Key Features: * Frosty Grey Finish: Adds a modern touch to your decor while complementing various color schemes. * Goodbye Dust Technology: Specially treated blades repel dust accumulation, making cleaning easier and less frequent. * Powerful Air Delivery: With a 1200mm sweep size, enjoy efficient cooling even in larger spaces. * High-Performance Motor: Ensures smooth operation and long lifespan, delivering reliable performance year after year. * Ribbed Aluminium Blades: Designed for optimal balance between style and functionality. * Energy Efficient: Consumes low power without compromising on performance or durability. * Easy Installation: Compatible with standard ceiling mounts, allowing easy installation for DIY enthusiasts. * Wide Range of Speeds: Offers multiple speed settings, enabling customized comfort based on personal preferences. This Usha Striker Platinum 1200mm Goodbye Dust Ceiling Fan combines sleek design, innovative features, and dependable performance. Experience enhanced air circulation and improved indoor air quality today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315da",
    "title": "Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold)",
    "description": "Product Name: Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold) Description: * Introducing the Usha Bellissa 1200mm Goodbye Dust Ceiling Fan, featuring an innovative design that helps reduce dust accumulation. * This fan boasts a sleek bright gold finish that adds a touch of elegance to any room decor. * With a sweep size of 1200mm, it provides efficient air circulation for large spaces up to 250 sq ft. * Its powerful motor delivers silent yet effective cooling performance with high-speed operation of 370 RPM. * Equipped with a remote control, you can easily adjust the fan speed from the comfort of your seat. * The fan also includes features such as sleep mode, timer function, and boost mode for added convenience. * Energy efficient, the Usha Bellissa ceiling fan is designed to consume less power while delivering superior performance. * Maintenance free, its goodbye dust technology ensures easy cleaning without the use of water or harsh chemicals. * Installation is simple with included mounting hardware and instructions. * Experience unmatched style, performance, and ease of use with the Usha Bellissa 1200mm Goodbye Dust Ceiling Fan (Bright Gold)."
  },
  {
    "_id": "62da57fa863ba7c37a1315dd",
    "title": "Usha Barbie You Can Be Anything Kids 1200mm Ceiling F
!"
  },
  {
    "_id": "62da57fa863ba7c37a1315ea",
    "title": "Usha Nabila 1200mm Energy Saving Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Nabila 1200mm Energy Saving Ceiling Fan (Rich Brown) Description: Introducing the Usha Nabila 1200mm Energy Saving Ceiling Fan, featuring a rich brown finish to complement any home decor. This fan is designed with energy efficiency in mind, using advanced technology to reduce power consumption without sacrificing performance. With a sweep size of 1200mm, it provides efficient air circulation for medium-sized rooms. Key Features: * Rich brown color adds warmth and style to your room * Advanced aerodynamic design ensures optimal air delivery while reducing noise levels * High-quality motor delivers powerful and consistent airflow * Specially treated blades prevent rust and corrosion over time * Energy saving mode reduces power usage by up to 35% compared to traditional fans * Includes a remote control for easy operation from anywhere in the room * Durable build quality ensures long-lasting use and minimal maintenance requirements * Suitable for ceiling heights between 2.8m - 3.4m * Easy installation process with all necessary hardware included Specifications: * Brand: Usha * Model: Nabila * Color: Rich Brown * Blade Material: Aluminum * Motor Type: Single phase induction motor * Speed Control: Remote controlled * Warranty: Contact manufacturer for details This Usha Nabila 1200mm Energy Saving Ceiling Fan is perfect for those looking to upgrade their existing fan or add a stylish yet functional piece to their space. Its energy-saving features make it an environmentally friendly choice, while its durable build and warranty ensure peace of mind. Order yours today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315f4",
    "title": "Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White) Product Description: * Introduction: Introduce the product, its brand name \"Usha\" which is known for quality fans, and highlight its key feature - universal fitting. Mention the color option available - Rich white. * Size & Dimensions: Specify the size of the fan to be 1400mm, suitable for medium-large sized rooms. Mention the dimensions of the fan to give an idea about its space requirement. * Materials Used: List down the materials used in constructing the fan such as high-quality plastic and metal, ensuring durability and long life. * Motor Type: Highlight the powerful motor with efficient air delivery, providing excellent cooling performance even at low speeds. Also, mention the noise level to ensure quiet operation. * Blade Design: Describe the number and design of blades, including their aerodynamic shape for optimal airflow and energy efficiency. Mention any additional features like rust-free or anti-dust properties. * Control Options: Explain the control options available, such as pull cords, wall controls or remote control, making it convenient for users to operate from anywhere in the room. * Installation: Provide details regarding installation process, compatibility with different ceiling types, and if professional installation is recommended. * Additional Features: If applicable, include other notable features such as summer-winter function, LED light kit, oscillating mechanism etc. * Conclusion: Summarize the main benefits and selling points of the Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White), emphasizing on its versatility and functionality. Note: SEO Keywords are not included in this format but suggested words could be 'Usha', 'Ceiling Fan', 'Universal Fitting', 'Rich White', 'Powerful Motor', 'Aerodynamic Blades' etc."
  },
  {
    "_id": "62da57fa863ba7c37a1315c3",
    "title": "Usha Bloom Primrose Sweep 1250mm Ceiling Fan (White)",
    "description": "Product Name: Usha Bloom Primrose Sweep 1250mm Ceiling Fan (White) Description: The Usha Bloom Primrose Sweep 1250mm Ceiling Fan is a high-quality, elegant, and efficient cooling solution for your home or office. This fan features a sleek white design with curved blades that are designed to provide maximum air delivery while maintaining a quiet operation. With a sweep size of 1250mm, it covers a large area, making it perfect for living rooms, bedrooms, and other spacious areas. Key Features: * Elegant white design with curved blades adds a touch of sophistication to any room * Large 1250mm sweep provides powerful air circulation for effective cooling * Quiet operation allows you to enjoy the cool breeze without disturbing noise * Energy-efficient motor ensures long-l
  },
  {
    "_id": "62da57fa863ba7c37a131613",
    "title": "Usha Striker 900mm Universal Ceiling Fan (Rich Ivory)",
    "description": "Product Name: Usha Striker 900mm Universal Ceiling Fan (Rich Ivory) Description: Introducing the Usha Striker 900mm Universal Ceiling Fan, featuring a rich ivory finish that adds elegance to any room. This fan is designed for universal use, making it suitable for both residential and commercial spaces. With a size of 900mm, it provides efficient air circulation, ensuring consistent comfort throughout your space. Key Features: * Rich ivory color for an elegant look * Suitable for both indoor and outdoor use * High-performance motor for powerful air delivery * Energy-efficient operation with low noise levels * Easy installation process * Durable build quality for long-lasting performance Specifications: * Size: 900mm * Finish: Rich Ivory * Material: Metal * Motor Type: High Performance * Warranty: N/A This ceiling fan from Usha is perfect for those looking for reliable and stylish cooling solution. Its sleek design, combined with its powerful performance, makes it an excellent choice for large rooms or areas where effective air circulation is essential. Whether you're using it at home or in a commercial setting, the Usha Striker 900mm Universal Ceiling Fan will not disappoint. Order yours today!"
  },
  {
    "_id": "62da57fa863ba7c37a1315f3",
    "title": "Usha Striker Millennium 1200mm Universal Ceiling Fan (Ultra Marine Blue)",
    "description": "Product Name: Usha Striker Millennium 1200mm Universal Ceiling Fan (Ultra Marine Blue) Description: Introducing the Usha Striker Millennium 1200mm Universal Ceiling Fan, featuring an Ultra Marine Blue color finish. This fan is designed to deliver powerful air circulation while adding a touch of style to your room decor. Its universal mounting system makes it suitable for both standard and sloped ceilings. Key Features: * Size: 1200mm (48 inches) sweep diameter, ideal for medium-sized rooms up to 150 sq ft. * Motor Type: High-performance motor with superior wind flow technology ensures efficient cooling even at low speeds. * Blade Material: Durable, high-quality plastic blades offer long-lasting performance and require minimal maintenance. * Color: Attractive Ultra Marine Blue finish complements modern interiors beautifully. * Mounting System: Includes a universal mounting bracket compatible with flat and angled surfaces, making installation easy and versatile. * Energy Efficiency: Designed for energy efficiency without compromising its cooling capabilities. * Noise Level: Smooth operation with reduced noise levels provides maximum comfort. This ceiling fan from Usha's Striker series offers excellent value for money due to its robust build quality and stylish appearance. With simple yet elegant aesthetics, the Ultra Marine Blue model adds a vibrant splash of color to any space. Enjoy optimal airflow throughout your living or workspace with ease and convenience. Please note that this product does not include warranty details; kindly contact the seller directly for more information regarding after-sales support. Keyword optimization has been considered when writing the description but may still require further adjustment based on specific SEO requirements."
  },
  {
    "_id": "62da57fa863ba7c37a131622",
    "title": "Usha Swift 1400mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Swift 1400mm Universal Ceiling Fan (Rich Brown) Description: Introducing the Usha Swift 1400mm Universal Ceiling Fan, featuring a rich brown color finish. This fan is designed to deliver powerful air circulation while maintaining a quiet operation, making it ideal for use in living rooms, bedrooms, or any other space up to 250 sq ft. The Usha Swift features aerodynamically designed blades with a sweep of 1400mm, providing efficient cooling performance at low noise levels. Its universal mounting system allows for easy installation in both standard and sloped ceilings, making it suitable for various room layouts. This ceiling fan comes equipped with a high-speed motor that ensures quick start-up and consistent performance even after long hours of usage. It also has an energy-efficient design that helps reduce electricity bills without compromising on comfort. Additional
usha Sonata 1200mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Sonata 1200mm Universal Ceiling Fan (Rich Brown) Description: Introducing the Usha Sonata 1200mm Universal Ceiling Fan, now available in a rich brown finish to complement your home decor. This fan is designed for universal use, making it suitable for any room in your house. With its impressive 1200mm sweep size, the Usha Sonata provides efficient air circulation to keep you cool during hot summer months. Its high-speed performance of up to 380 RPM ensures quick cooling, while its low-speed setting helps maintain comfortable temperatures all year round. The fan features an aerodynamic design with swept back aluminum blades that reduce aircutting noise, providing a peaceful environment for sleeping or working. It also has a double ball bearing mechanism for long-lasting durability and silent operation. Additionally, the Usha Sonata comes with a two-way adjustable mounting system, allowing for easy installation on both standard and sloped ceilings. Key Features: * Suitable for all rooms * 1200mm sweep size for efficient air circulation * High-speed performance of up to 380 RPM * Low-noise operation due to aerodynamic design * Double ball bearing mechanism for longevity * Two-way adjustable mounting system for versatile installation * Rich brown color adds elegance and style to any space This Usha ceiling fan offers excellent value for money and promises reliable performance backed by the trusted reputation of Usha brand. Upgrade your living space with the modern design and powerful functionality of the Usha Sonata 1200mm Universal Ceiling Fan (Rich Brown)."
  },
  {
    "_id": "62da57fa863ba7c37a1315c4",
    "title": "Usha Bloom Primrose Sweep 1250mm Ceiling Fan (Golden And Cherry)",
    "description": "Product Name: Usha Bloom Primrose Sweep 1250mm Ceiling Fan (Golden and Cherry) Product Description: * Type: Ceiling fan * Brand: Usha * Model: Bloom Primrose * Blade span: 1250mm (49.2 inches) * Finish: Golden and Cherry * Materials: High-quality metal and wood * Controls: Pull cord regulation * Warranty: Contact manufacturer for details * Special features: Energy-efficient motor, stylish design, quiet operation * Applicable room size: Medium to large rooms * Voltage: 230V AC, 50Hz * Weight: 7kg * Additional accessories included: None * Other features: Decorative and functional, provides smooth airflow, easy installation This ceiling fan from Usha is an excellent choice for those who want a decorative yet efficient cooling solution for their homes or offices. With its elegant golden and cherry finish, the fan adds a touch of sophistication to any space while providing powerful air circulation. The high-quality materials used in construction ensure durability and long-lasting performance. The energy-efficient motor ensures low power consumption without compromising on the fan's efficiency. It comes with pull cord controls for ease of use, making it simple to adjust the speed according to your comfort level. The fan has been designed to operate quietly, ensuring minimal noise disturbance. With a blade sweep of 1250mm, the Usha Bloom Primrose fan is suitable for medium to large-sized rooms. Its stylish design complements both modern and traditional decors, making it a versatile addition to any space. Installation is straightforward and hassle-free, thanks to clear instructions provided by the manufacturer. Overall, the Usha Bloom Primrose Sweep 1250mm Ceiling Fan (Golden and Cherry) offers great value for money, combining style and functionality at an affordable price point."
  },
  {
    "_id": "62da57fa863ba7c37a1315c7",
    "title": "Usha Bloom Magnolia Sweep 1250mm Ceiling Fan (White)",
    "description": "Product Name: Usha Bloom Magnolia Sweep 1250mm Ceiling Fan (White) Description: Introducing the Usha Bloom Magnolia Sweep 1250mm Ceiling Fan, a stylish and efficient addition to any room. This fan boasts a sleek white finish and elegant magnolia blades that complement modern decor while providing powerful air circulation. With a sweep of 1250mm, it covers large spaces with ease, ensuring consistent comfort throughout your home or office. Key Features: * Stylish design with a clean white finish and magnolia bl
  },
  {
    "_id": "62da57fa863ba7c37a131602",
    "title": "Usha Neo Plus 1200mm Universal Ceiling Fan (Rich Ivory)",
    "description": "Product Name: Usha Neo Plus 1200mm Universal Ceiling Fan (Rich Ivory) Description: Introducing the Usha Neo Plus 1200mm Universal Ceiling Fan, featuring a rich ivory finish. This fan is designed to deliver powerful air circulation while adding a touch of elegance to your space. Its universal fit makes it suitable for any room size or ceiling height. With a sweep size of 1200mm, this fan ensures maximum coverage and efficient cooling. Key Features: * Rich Ivory Finish: Adds an elegant touch to your decor while complementing various interiors. * Powerful Air Delivery: Equipped with high-speed aluminum blades that ensure optimal air delivery even at low speeds. * Energy Efficient Motor: Designed for long-lasting performance and reduced energy consumption, helping you save on electricity bills. * Whisper Quiet Operation: Experience smooth operation without disturbances due to its aerodynamically designed motor and blade structure. * Wide Range Compatibility: Suitable for all mountings, including standard, sloped, or angled ceilings, making it perfect for installation in living rooms, bedrooms, kitchens, and more. * Easy Installation: Includes a user manual and required hardware for easy DIY installation, saving time and effort. Specifications: * Brand: Usha * Model: Neo Plus * Size: 1200mm * Color: Rich Ivory * Material: Aluminum Blades, Plastic Body * Control Type: Pull Chain Regulator * Number of Speeds: 3 * RPM: 350 (Low), 450 (Medium), 600 (High) * Voltage: 220V - 240V AC, Single Phase * Warranty: Please check with manufacturer or seller Note: Always refer to the manufacturer's website or consult with their customer support team regarding warranty details."
  },
  {
    "_id": "62da57fa863ba7c37a131606",
    "title": "Usha Xavia 1200mm Universal Ceiling Fan (Rich Brown)",
    "description": "Product Name: Usha Xavia 1200mm Universal Ceiling Fan (Rich Brown) Description: * The Usha Xavia ceiling fan is designed with a universal fit, making it suitable for any room in your home or office. * Its rich brown color adds warmth and sophistication to your decor, while the sleek design complements both traditional and modern spaces. * With a size of 1200mm, this fan provides efficient air circulation to keep you cool during hot summer days. * It features a high-speed motor that ensures powerful performance, along with an aerodynamic blade design for reduced noise and energy consumption. * The fan also includes a remote control for easy operation from anywhere in the room. * Additionally, the Usha Xavia comes with a two-year warranty for added peace of mind. Note: This product description focuses on providing relevant information about the Usha Xavia ceiling fan, including its features and benefits. However, it does not include SEO keywords or warranty details as requested."
  },
  {
    "_id": "62da57fa863ba7c37a131608",
    "title": "Usha Trump Plus 1200mm Universal Ceiling Fan (Rich White)",
    "description": "Product Name: Usha Trump Plus 1200mm Universal Ceiling Fan (Rich White) Description: Introducing the Usha Trump Plus 1200mm Universal Ceiling Fan, featuring a rich white finish to complement any decor. This fan is designed for universal use and comes with a large 1200mm sweep size, providing efficient air circulation throughout your space. Its powerful motor ensures smooth operation at low noise levels, making it perfect for bedrooms, living rooms, or offices. Key Features: * Universal fit design suitable for all types of ceilings * Large 1200mm sweep size for optimal air circulation * Powerful motor ensuring quiet and smooth operation * Rich white finish adds elegance and style to any room * Ideal for both residential and commercial spaces Specifications: * Brand: Usha * Model Number: Trump Plus * Size: 1200mm * Color: Rich White * Material: Metal * Warranty: Please contact manufacturer for warranty details Note: We strive to provide accurate and up-to-date descriptions; however, we recommend checking the manufacturer's website for further specifications and warranties before purchasing."
  },
  {
    "_id": "62da57fa863ba7c37a13160a",
    "title": "Usha Racer 1200mm Universal Ceiling Fan (Rich Red)",
    "description": "Product Name: Usha Racer 1200mm Universal Ceiling Fan (Rich Red) Description: Introducing the Usha Racer 1200mm Universal Ceiling Fan, now available in a stunning Rich Red finish. This fan is designed to deliver powerful air circulation while adding a touch of elegance to your space. With its univers
Striker 1200mm Universal Ceiling Fan is designed to deliver powerful cooling performance while maintaining an energy-efficient operation. Its matte brown finish adds style and elegance to any room decor. With its high-quality construction using robust materials like plastic and metal, the fan promises durability and longevity. The ceiling fan features an energy-efficient AC motor with double ball bearings that ensure smooth and quiet operation. It comes equipped with three durable PVC blades having an aerodynamic design that maximizes air delivery, providing efficient cooling throughout the space. For added convenience, the regulator allows you to adjust the fan's speed according to your preference. Additionally, it boasts rust-resistant coatings ensuring long-lasting use even in humid conditions. This versatile ceiling fan is ideal for rooms of various sizes, making it perfect for both residential and commercial spaces."
  },
]

# Preprocess and encode the descriptions
descriptions = [product['title'] for product in products]
encoded_descriptions = model.encode(descriptions)

# Function to recommend products based on a query with feedback loop
def recommend_product(query, excluded_indices=[]):
    # Preprocess and encode the query
    query_embedding = model.encode([query])

    # Compute similarities
    similarities = cosine_similarity(query_embedding, encoded_descriptions).flatten()

    # Sort the indices of similarities in descending order
    sorted_indices = similarities.argsort()[::-1]

    # Iterate over sorted indices and yield product recommendations
    for index in sorted_indices:
        if index not in excluded_indices:
            yield products[index]

# Function to handle the interactive recommendation process
def interactive_recommendation():
    while True:
        query = input("\nPlease enter your query (e.g., 'gold fan 1200mm') or press 'q' to quit: ")
        if query.lower() == 'q':
            print("Exiting program. Thank you!")
            break

        excluded_indices = []
        recommender = recommend_product(query, excluded_indices)

        for recommended_product in recommender:
            # Show the recommendation to the user
            print(f"\nRecommended Product: {recommended_product['title']}")
            feedback = input("Is this recommendation satisfactory? (True/False) or 'q' to quit: ").strip().lower()

            if feedback == 'true':
                print("Recommendation accepted. Thank you!\n")
                break
            elif feedback == 'q':
                print("Exiting program. Thank you!")
                return
            else:
                excluded_indices.append(products.index(recommended_product))
                print("Let's try another recommendation...")

# Run the interactive recommendation
interactive_recommendation()
# Out:
# Please enter your query (e.g., 'gold fan 1200mm') or press 'q' to quit: 1200mmceling fan
#
# Recommended Product: Usha Nabila 1200mm Energy Saving Ceiling Fan (Rich Brown)
# Is this recommendation satisfactory? (True/False) or 'q' to quit: True
# Recommendation accepted. Thank you!
#
#
# Please enter your query (e.g., 'gold fan 1200mm') or press 'q' to quit: 1200mmcelling fan
#
# Recommended Product: Usha Nabila 1200mm Energy Saving Ceiling Fan (Rich Brown)
# Is this recommendation satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Recommended Product: Usha Racer 1200mm Universal Ceiling Fan (Rich Red)
# Is this recommendation satisfactory? (True/False) or 'q' to quit: 1200mm celling fan
# Let's try another recommendation...
#
# Recommended Product: Usha Striker 1200mm Universal Ceiling Fan (Matte Brown)
# Is this recommendation satisfactory? (True/False) or 'q' to quit: 4 blade fan
# Let's try another recommendation...
#
# ...

# %%
import json
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Your dataset
products = [


  {
    "_id": "62da57fa863ba7c37a131615",
    "title": "Usha Striker 1200mm Universal Ceiling Fan (Matte Brown)",
    "description": "Product Name: Usha Striker 1200mm Universal Ceiling Fan (Matte Brown) Description: * Product Dimensions: Diameter - 1200mm, Height - 350mm * Material: High-quality plastic and metal * Finish: Matte brown * Motor Type: Energy-efficient AC motor with double ball bearing for smooth operation * Blades: 3 durable PVC blades with aerodynamic design for maximum air delivery * Speed Control: Regulator included for variable speed control * Warranty: N/A * Additional Features: Rust-resistant coating, low noise during operation, suitable for all room sizes. This Usha Striker 1200mm Universal Ceiling Fan is designed to deliver powerful cooling performance while maintaining an energy-efficient operation. Its matte brown finish adds style and elegance to any room decor. With its high-quality construction using robust materials like plastic and metal, the fan promises durability and longevity. The ceiling fan features an energy-efficient AC motor with double ball bearings that ensure smooth and quiet operation. It comes equipped with three durable PVC blades having an aerodynamic design that maximizes air delivery, providing efficient cooling throughout the space. For added convenience, the regulator allows you to adjust the fan's speed according to your preference. Additionally, it boasts rust-resistant coatings ensuring long-lasting use even in humid conditions. This versatile ceiling fan is ideal for rooms of various sizes, making it perfect for both residential and commercial spaces."
  },]

# Preprocess and encode the descriptions if not already done
try:
    # Try to load the precomputed embeddings from a file
    with open('encoded_descriptions.json', 'r') as file:
        encoded_descriptions = json.load(file)
except FileNotFoundError:
    # If the file does not exist, compute the embeddings and save them
    descriptions = [product['description'] for product in products]
    encoded_descriptions = model.encode(descriptions).tolist()
    with open('encoded_descriptions.json', 'w') as file:
        json.dump(encoded_descriptions, file)

# Try to load the state of previous interactions
try:
    with open('interaction_state.json', 'r') as file:
        interaction_state = json.load(file)
except FileNotFoundError:
    interaction_state = {}

# Function to update the interaction state file
def update_interaction_state(query, excluded_indices):
    interaction_state[query] = excluded_indices
    with open('interaction_state.json', 'w') as file:
        json.dump(interaction_state, file)

# Function to recommend products based on a query with feedback loop
def recommend_product(query, excluded_indices=[]):
    query_embedding = model.encode([query])
    similarities = cosine_similarity(query_embedding, encoded_descriptions).flatten()
    sorted_indices = similarities.argsort()[::-1]

    for index in sorted_indices:
        if index not in excluded_indices:
            yield products[index]

# Function to handle the interactive recommendation process
def interactive_recommendation():
    while True:
        query = input("\nPlease enter your query or press 'q' to quit: ").strip().lower()
        if query == 'q':
            print("Exiting program. Thank you!")
            break

        excluded_indices = interaction_state.get(query, [])
        recommender = recommend_product(query, excluded_indices)

        for recommended_product in recommender:
            print(f"\nRecommended Product: {recommended_product['title']}")
            feedback = input("Is this recommendation satisfactory? (True/False) or 'q' to quit: ").strip().lower()

            if feedback == 'true':
                print("Recommendation accepted. Thank you!\n")
                break
            elif feedback == 'q':
                print("Exiting program. Thank you!")
                return
            else:
                excluded_indices.append(products.index(recommended_product))
                update_interaction_state(query, excluded_indices)
                print("Let's try another recommendation...")

# Run the interactive recommendation
interactive_recommendation()
# Out:
# Please enter your query or press 'q' to quit: 1200mm fan
#
# Recommended Product: Usha Striker Plus 1200mm Energy Saving Ceiling Fan (White)
# Is this recommendation satisfactory? (True/False) or 'q' to quit: True
# Recommendation accepted. Thank you!
#
#
# Please enter your query or press 'q' to quit: 1200mm fan
#
# Recommended Product: Usha Striker Plus 1200mm Energy Saving Ceiling Fan (White)
# Is this recommendation satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Recommended Product: Usha Striker 1200mm Universal Ceiling Fan (Matte Brown)
# Is this recommendation satisfactory? (True/False) or 'q' to quit: Flase
# Let's try another recommendation...
#
# Recommended Product: Usha Allure Deluxe 1400mm Universal Ceiling Fan (Rich White)
# Is this recommendation satisfactory? (True/False) or 'q' to quit: Flase
# Let's try another recommendation...
#
# Recommended Product: Usha Striker 1400mm Universal Ceiling Fan (Matte Brown)
# ...

# %%
import json
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# model = SentenceTransformer('sksayril/all-minilm-v6')

# Your dataset
try:
    with open('/content/converted_data.json', 'r') as file:
        products = json.load(file)
except FileNotFoundError:
    print("Error: Products data file ('/content/converted_data.json') not found.")
    exit()


try:

    with open('encoded_descriptions.json', 'r') as file:
        encoded_descriptions = json.load(file)
except FileNotFoundError:
    # If the file does not exist, compute the embeddings and save them
    descriptions = [product['title'] for product in products]
    encoded_descriptions = model.encode(descriptions).tolist()
    with open('encoded_descriptions.json', 'w') as file:
        json.dump(encoded_descriptions, file)

# Try to load the state of previous interactions
try:
    with open('interaction_state.json', 'r') as file:
        interaction_state = json.load(file)
except FileNotFoundError:
    interaction_state = {}

# Function to update the interaction state file
def update_interaction_state(query, excluded_indices):
    interaction_state[query] = excluded_indices
    with open('interaction_state.json', 'w') as file:
        json.dump(interaction_state, file)

# Function to recommend products based on a query with feedback loop
def recommend_product(query, excluded_indices=[]):
    query_embedding = model.encode([query])
    similarities = cosine_similarity(query_embedding, encoded_descriptions).flatten()
    sorted_indices = similarities.argsort()[::-1]

    for index in sorted_indices:
        if index not in excluded_indices:
            yield products[index]

# Function to handle the interactive recommendation process
def interactive_recommendation():
    while True:
        query = input("\nPlease enter your query or press 'q' to quit: ").strip().lower()
        if query == 'q':
            print("Exiting program. Thank you!")
            break

        excluded_indices = interaction_state.get(query, [])
        recommender = recommend_product(query, excluded_indices)

        for recommended_product in recommender:
            print(f"\nRecommended Product: {recommended_product['title']}")
            feedback = input("Is this recommendation satisfactory? (True/False) or 'q' to quit: ").strip().lower()

            if feedback == 'true':
                print("Recommendation accepted. Thank you!\n")
                break
            elif feedback == 'q':
                print("Exiting program. Thank you!")
                return
            else:
                excluded_indices.append(products.index(recommended_product))
                update_interaction_state(query, excluded_indices)
                print("Let's try another recommendation...")

# Run the interactive recommendation
interactive_recommendation()
# Out:
# Please enter your query or press 'q' to quit: white beasin
#
# Recommended Product: MARINO Silver White
# Is this recommendation satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Recommended Product: MARINO Candy White
# Is this recommendation satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Recommended Product: Marino Candy White
# Is this recommendation satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Recommended Product: MARINO Candy White
# Is this recommendation satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Recommended Product: Ispira LILAC WHITE (48 X 96 INCH)
# Is this recommendation satisfactory? (True/False) or 'q' to quit: True
# Recommendation accepted. Thank you!
#
#
# Please enter your query or press 'q' to quit: white beasin
#
# Recommended Product: Ispira LILAC WHITE (48 X 96 INCH)
# ...

# %%
import json
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Your dataset
try:
    with open('/content/converted_data.json', 'r') as file:
        products = json.load(file)

    # Add a 'feedback' key to each product and initialize it as an empty list
    for product in products:
        product['feedback'] = []

except FileNotFoundError:
    print("Error: Products data file ('/content/converted_data.json') not found.")
    exit()

# Try to load the state of previous interactions
try:
    with open('interaction_state.json', 'r') as file:
        interaction_state = json.load(file)
except FileNotFoundError:
    interaction_state = {}

# Function to update the interaction state file
def update_interaction_state(query, excluded_indices):
    interaction_state[query] = excluded_indices
    with open('interaction_state.json', 'w') as file:
        json.dump(interaction_state, file)

# Function to recommend products based on a query with feedback loop
def recommend_products(query, num_recommendations=5, excluded_indices=[]):
    query_embedding = model.encode([query])
    similarities = cosine_similarity(query_embedding, encoded_descriptions).flatten()
    sorted_indices = similarities.argsort()[::-1]

    recommended_products = []
    for index in sorted_indices:
        if len(recommended_products) >= num_recommendations:
            break
        if index not in excluded_indices:
            recommended_products.append(products[index])

    return recommended_products

# Function to handle the interactive recommendation process
def interactive_recommendation():
    while True:
        query = input("\nPlease enter your query or press 'q' to quit: ").strip().lower()
        if query == 'q':
            print("Exiting program. Thank you!")
            break

        excluded_indices = interaction_state.get(query, [])
        recommended_products = recommend_products(query, num_recommendations=5, excluded_indices=excluded_indices)

        # Show all 5 recommended products first
        print("\nRecommended Products:")
        for i, recommended_product in enumerate(recommended_products, start=1):
            print(f"{i}. {recommended_product['title']}")

        for i, recommended_product in enumerate(recommended_products, start=1):
            feedback = input(f"\nIs Product {i} satisfactory? (True/False) or 'q' to quit: ").strip().lower()

            if feedback == 'true':
                recommended_product['feedback'].append(True)  # Add 'True' to feedback list
                update_interaction_state(query, excluded_indices)
                print("Recommendation accepted. Thank you!\n")
            elif feedback == 'q':
                print("Exiting program. Thank you!")
                return
            else:
                excluded_indices.append(products.index(recommended_product))
                update_interaction_state(query, excluded_indices)
                print("Let's try another recommendation...")

# Run the interactive recommendation
interactive_recommendation()
# Out:
# Please enter your query or press 'q' to quit: Beasin
#
# Recommended Products:
# 1. Taparia 330mm Grade IS 841-1983 Ball Pein Hammer With Handle WH 500 BC
# 2. Hindware Cora Chrome Bib Cock With Wall Flange F440003
# 3. Hindware Amazon Chrome Bib Cock F320004CP
# 4. Hindware Cora Chrome Bath Spout F440006CP
# 5. Hindware Cora Chrome 2 in 1 Bib Cock F440004CP
#
# Is Product 1 satisfactory? (True/False) or 'q' to quit: True
# Recommendation accepted. Thank you!
#
#
# Is Product 2 satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Is Product 3 satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Is Product 4 satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Is Product 5 satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Please enter your query or press 'q' to quit: Beasin
#
# Recommended Products:
# ...

# %%
import json
import os
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Constants for embedding files
EMBEDDINGS_FILE = 'encoded_descriptions.npy'

# Function to save embeddings to a file
def save_embeddings(embeddings, filename):
    np.save(filename, embeddings)

# Function to load embeddings from a file
def load_embeddings(filename):
    return np.load(filename)

# Your dataset
try:
    with open('/content/converted_data.json', 'r') as file:
        products = json.load(file)

    # Check if embeddings file exists
    if os.path.exists(EMBEDDINGS_FILE):
        encoded_descriptions = load_embeddings(EMBEDDINGS_FILE)
    else:
        # Calculate and save embeddings for descriptions
        descriptions = [product['description'] for product in products]
        encoded_descriptions = model.encode(descriptions)
        save_embeddings(encoded_descriptions, EMBEDDINGS_FILE)

    # Add a 'feedback' key to each product and initialize it as an empty list
    for product in products:
        product['feedback'] = []

except FileNotFoundError:
    print("Error: Products data file ('/content/converted_data.json') not found.")
    exit()

# Try to load the state of previous interactions
try:
    with open('interaction_state.json', 'r') as file:
        interaction_state = json.load(file)
except FileNotFoundError:
    interaction_state = {}

# Function to update the interaction state file
def update_interaction_state(query, excluded_indices):
    interaction_state[query] = excluded_indices
    with open('interaction_state.json', 'w') as file:
        json.dump(interaction_state, file)

# Function to recommend products based on a query with feedback loop
def recommend_products(query, num_recommendations=5, excluded_indices=[]):
    query_embedding = model.encode([query])

    similarities = cosine_similarity(query_embedding, encoded_descriptions).flatten()
    sorted_indices = similarities.argsort()[::-1]

    recommended_products = []
    for index in sorted_indices:
        if len(recommended_products) >= num_recommendations:
            break
        if index not in excluded_indices:
            recommended_products.append(products[index])

    return recommended_products

# Function to handle the interactive recommendation process
def interactive_recommendation():
    while True:
        query = input("\nPlease enter your query or press 'q' to quit: ").strip().lower()
        if query == 'q':
            print("Exiting program. Thank you!")
            break

        excluded_indices = interaction_state.get(query, [])
        recommended_products = recommend_products(query, num_recommendations=5, excluded_indices=excluded_indices)

        # Show all 5 recommended products first
        print("\nRecommended Products:")
        for i, recommended_product in enumerate(recommended_products, start=1):
            print(f"{i}. {recommended_product['title']} - {recommended_product['description']}")

        for i, recommended_product in enumerate(recommended_products, start=1):
            feedback = input(f"\nIs Product {i} satisfactory? (True/False) or 'q' to quit: ").strip().lower()

            if feedback == 'true':
                recommended_product['feedback'].append(True)  # Add 'True' to feedback list
                update_interaction_state(query, excluded_indices)
                print("Recommendation accepted. Thank you!\n")
            elif feedback == 'q':
                print("Exiting program. Thank you!")
                return
            else:
                excluded_indices.append(products.index(recommended_product))
                update_interaction_state(query, excluded_indices)
                print("Let's try another recommendation...")

# Run the interactive recommendation
interactive_recommendation()
# Out:
# Please enter your query or press 'q' to quit: Beasin
#
# Recommended Products:
# 1. Taparia 330mm Grade IS 841-1983 Ball Pein Hammer With Handle WH 500 BC - Type : Ball Pein
# 2. Cera Chelsea  Bib Cock F1016151 (Chrome) - Chelsea Type:Bib Cock
# 3. Mankit MKT 063 Quartz Single Bowl Kitchen Sink (Granite) - c
# 4. Hindware Cora Chrome Tall Pillar Cock F440002CP - Cora Pillar Cock Tall
# 5. Jaquar AKP-CHR-35755PS Kubix Prime Spare Toilet Roll Holder (Chrome) - Stainless Steel
#
# Is Product 1 satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Is Product 2 satisfactory? (True/False) or 'q' to quit: True
# Recommendation accepted. Thank you!
#
#
# Is Product 3 satisfactory? (True/False) or 'q' to quit: True
# Recommendation accepted. Thank you!
#
#
# Is Product 4 satisfactory? (True/False) or 'q' to quit: True
# Recommendation accepted. Thank you!
#
#
# Is Product 5 satisfactory? (True/False) or 'q' to quit: False
# ...

# %%
# !pip install streamlit

# %%
import json
import os
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Constants for embedding files
EMBEDDINGS_FILE = 'encoded_descriptions.npy'

# Function to save embeddings to a file
def save_embeddings(embeddings, filename):
    np.save(filename, embeddings)

# Function to load embeddings from a file
def load_embeddings(filename):
    return np.load(filename)

# Your dataset
try:
    with open('/content/converted_data.json', 'r') as file:
        products = json.load(file)

    # Check if embeddings file exists
    if os.path.exists(EMBEDDINGS_FILE):
        encoded_descriptions = load_embeddings(EMBEDDINGS_FILE)
    else:
        # Calculate and save embeddings for descriptions
        descriptions = [product['description'] for product in products]
        encoded_descriptions = model.encode(descriptions)
        save_embeddings(encoded_descriptions, EMBEDDINGS_FILE)

    # Add a 'feedback' key to each product and initialize it as an empty list
    for product in products:
        product['feedback'] = []

except FileNotFoundError:
    print("Error: Products data file ('/content/converted_data.json') not found.")
    exit()

# Try to load the state of previous interactions
try:
    with open('interaction_state.json', 'r') as file:
        interaction_state = json.load(file)
except FileNotFoundError:
    interaction_state = {}

# Function to update the interaction state file
def update_interaction_state(query, excluded_indices):
    interaction_state[query] = excluded_indices
    with open('interaction_state.json', 'w') as file:
        json.dump(interaction_state, file)

# Function to recommend products based on a query with feedback loop
def recommend_products(query, num_recommendations=5, excluded_indices=[]):
    query_embedding = model.encode([query])

    similarities = cosine_similarity(query_embedding, encoded_descriptions).flatten()
    sorted_indices = similarities.argsort()[::-1]

    recommended_products = []
    for index in sorted_indices:
        if len(recommended_products) >= num_recommendations:
            break
        if index not in excluded_indices:
            recommended_products.append(products[index])

    return recommended_products

# Function to handle the interactive recommendation process
def interactive_recommendation():
    while True:
        query = input("\nPlease enter your query or press 'q' to quit: ").strip().lower()
        if query == 'q':
            print("Exiting program. Thank you!")
            break

        excluded_indices = interaction_state.get(query, [])
        recommended_products = recommend_products(query, num_recommendations=5, excluded_indices=excluded_indices)

        # Show all 5 recommended products first
        print("\nRecommended Products:")
        for i, recommended_product in enumerate(recommended_products, start=1):
            print(f"{i}. {recommended_product['title']} - {recommended_product['description']}")

        feedbacks = []  # List to store feedback for all 5 products

        for i, recommended_product in enumerate(recommended_products, start=1):
            feedback = input(f"\nIs Product {i} satisfactory? (True/False) or 'q' to quit: ").strip().lower()

            if feedback == 'true':
                feedbacks.append(True)  # Add 'True' to feedback list
            elif feedback == 'q':
                print("Exiting program. Thank you!")
                return
            else:
                feedbacks.append(False)

        # Update feedback for all 5 products in bulk
        for i, recommended_product in enumerate(recommended_products, start=1):
            recommended_product['feedback'].extend(feedbacks)  # Update feedback for all 5 products
            excluded_indices.append(products.index(recommended_product))

        update_interaction_state(query, excluded_indices)
        print("Recommendations accepted. Thank you!\n")

# Run the interactive recommendation
interactive_recommendation()
# Out:
# Please enter your query or press 'q' to quit: beasin
#
# Recommended Products:
# 1. Taparia 300mm Grade IS 841-1983 Ball Pein Hammer With Handle WH 200 BC - Type : Ball Pein
# 2. Taparia 375mm Grade IS 841-1983 Ball Pein Hammer With Handle WH 800 BC - Type : Ball Pein
# 3. Taparia 375mm Grade IS 841-1983 Ball Pein Hammer With Handle WH 600 B - Type : Ball Pein
# 4. Taparia 260mm Grade IS 841-1983 Ball Pein Hammer With Handle WH 110 B - Type : Ball Pein
# 5. Taparia 315mm Grade IS 841-1983 Ball Pein Hammer With Handle WH 340 B - Type : Ball Pein
#
# Is Product 1 satisfactory? (True/False) or 'q' to quit: True
#
# Is Product 2 satisfactory? (True/False) or 'q' to quit: False
#
# Is Product 3 satisfactory? (True/False) or 'q' to quit: True
#
# Is Product 4 satisfactory? (True/False) or 'q' to quit: False
#
# Is Product 5 satisfactory? (True/False) or 'q' to quit: True
# Recommendations accepted. Thank you!
#
#
# Please enter your query or press 'q' to quit: beasin
#
# ...

# %%
import json
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Function to save embeddings to a file
def save_embeddings(embeddings, filename):
    np.save(filename, embeddings)

# Function to load embeddings from a file
def load_embeddings(filename):
    return np.load(filename)

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Your dataset
try:
    with open('/content/converted_data.json', 'r') as file:
        products = json.load(file)

    # Add a 'feedback' key to each product and initialize it as an empty list
    for product in products:
        product['feedback'] = []

except FileNotFoundError:
    print("Error: Products data file ('/content/converted_data.json') not found.")
    exit()

# Try to load the state of previous interactions
try:
    with open('interaction_state.json', 'r') as file:
        interaction_state = json.load(file)
except FileNotFoundError:
    interaction_state = {}

# Try to load pre-computed embeddings or compute and save them
embedding_file = 'product_embeddings.npy'
try:
    encoded_descriptions = load_embeddings(embedding_file)
except FileNotFoundError:
    # Compute and save embeddings
    descriptions = [product['title'] for product in products]
    encoded_descriptions = model.encode(descriptions)
    save_embeddings(encoded_descriptions, embedding_file)

# Function to update the interaction state file
def update_interaction_state(query, excluded_indices):
    interaction_state[query] = excluded_indices
    with open('interaction_state.json', 'w') as file:
        json.dump(interaction_state, file)

# Function to recommend products based on a query with feedback loop
def recommend_products(query, num_recommendations=5, excluded_indices=[]):
    query_embedding = model.encode([query])
    similarities = cosine_similarity(query_embedding, encoded_descriptions).flatten()
    sorted_indices = similarities.argsort()[::-1]

    recommended_products = []
    for index in sorted_indices:
        if len(recommended_products) >= num_recommendations:
            break
        if index not in excluded_indices:
            recommended_products.append(products[index])

    return recommended_products

# Function to handle the interactive recommendation process
def interactive_recommendation():
    while True:
        query = input("\nPlease enter your query or press 'q' to quit: ").strip().lower()
        if query == 'q':
            print("Exiting program. Thank you!")
            break

        excluded_indices = interaction_state.get(query, [])
        recommended_products = recommend_products(query, num_recommendations=5, excluded_indices=excluded_indices)

        # Show all 5 recommended products first
        print("\nRecommended Products:")
        for i, recommended_product in enumerate(recommended_products, start=1):
            print(f"{i}. {recommended_product['title']}")

        for i, recommended_product in enumerate(recommended_products, start=1):
            feedback = input(f"\nIs Product {i} satisfactory? (True/False) or 'q' to quit: ").strip().lower()

            if feedback == 'true':
                recommended_product['feedback'].append(True)  # Add 'True' to feedback list
                update_interaction_state(query, excluded_indices)
                print("Recommendation accepted. Thank you!\n")
            elif feedback == 'q':
                print("Exiting program. Thank you!")
                return
            else:
                excluded_indices.append(products.index(recommended_product))
                update_interaction_state(query, excluded_indices)
                print("Let's try another recommendation...")

# Run the interactive recommendation
interactive_recommendation()
# Out:
# Please enter your query or press 'q' to quit: godrej 3060
#
# Recommended Products:
# 1. Godrej 1140mm Two Point Panic Bar 7864
# 2. Legrand Myrius Nextgen Double RJ11 Telephone White (679263)
# 3. Godrej 300mm Popular Mortise Theo Handle SS 4909
# 4. Legrand Myrius Nextgen RJ11 Telephone White (679262)
# 5. Godrej Popular Mortise NEH 13 Rossette 6058
#
# Is Product 1 satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Is Product 2 satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Is Product 3 satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Is Product 4 satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Is Product 5 satisfactory? (True/False) or 'q' to quit: False
# Let's try another recommendation...
#
# Please enter your query or press 'q' to quit: godrej 3060
#
# Recommended Products:
# ...

# %%
import json
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Function to save embeddings to a file
def save_embeddings(embeddings, filename):
    np.save(filename, embeddings)

# Function to load embeddings from a file
def load_embeddings(filename):
    return np.load(filename)

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Load the dataset
try:
    with open('/content/converted_data.json', 'r') as file:
        products = json.load(file)

    # Add a 'feedback' key to each product and initialize it as an empty list
    for product in products:
        product['feedback'] = []

except FileNotFoundError:
    print("Error: Products data file ('/content/converted_data.json') not found.")
    exit()

# Try to load the state of previous interactions
try:
    with open('interaction_state.json', 'r') as file:
        interaction_state = json.load(file)
except FileNotFoundError:
    interaction_state = {}

# Try to load pre-computed embeddings or compute and save them
embedding_file = 'product_embeddings.npy'
try:
    encoded_descriptions = load_embeddings(embedding_file)
except FileNotFoundError:
    # Compute and save embeddings
    descriptions = [f"{product['model']} {product['title']}" for product in products]
    encoded_descriptions = model.encode(descriptions)
    save_embeddings(encoded_descriptions, embedding_file)

# Function to update the interaction state file
def update_interaction_state(query, excluded_indices):
    interaction_state[query] = excluded_indices
    with open('interaction_state.json', 'w') as file:
        json.dump(interaction_state, file)

# Function to recommend products based on a query with feedback loop
def recommend_products(query, num_recommendations=5, excluded_indices=[]):
    query_embedding = model.encode([query])
    model_query = query.split(' ')[0]  # Extract the model from the query

    # First, search for products with matching model
    model_match_indices = [i for i, product in enumerate(products) if product['model'] == model_query]

    if model_match_indices:
        model_match_indices = np.array(model_match_indices)
        similarities = cosine_similarity(query_embedding, encoded_descriptions[model_match_indices]).flatten()
        sorted_indices = model_match_indices[np.argsort(similarities)[::-1]]
    else:
        # If no matching models found, fallback to title-based recommendations
        similarities = cosine_similarity(query_embedding, encoded_descriptions).flatten()
        sorted_indices = np.argsort(similarities)[::-1]

    recommended_products = []
    for index in sorted_indices:
        if len(recommended_products) >= num_recommendations:
            break
        if index not in excluded_indices:
            recommended_products.append(products[index])

    return recommended_products

# Function to handle the interactive recommendation process
def interactive_recommendation():
    while True:
        query = input("\nPlease enter your query or press 'q' to quit: ").strip().lower()
        if query == 'q':
            print("Exiting program. Thank you!")
            break

        excluded_indices = interaction_state.get(query, [])
        recommended_products = recommend_products(query, num_recommendations=5, excluded_indices=excluded_indices)

        if not recommended_products:
            print(f"No recommendations found for the model: {query.split(' ')[0]}")
            continue

        # Show all 5 recommended products first
        print("\nRecommended Products:")
        for i, recommended_product in enumerate(recommended_products, start=1):
            print(f"{i}. {recommended_product['title']} (Model: {recommended_product['model']})")

        for i, recommended_product in enumerate(recommended_products, start=1):
            feedback = input(f"\nIs Product {i} satisfactory? (True/False) or 'q' to quit: ").strip().lower()

            if feedback == 'true':
                recommended_product['feedback'].append(True)  # Add 'True' to feedback list
                excluded_indices.append(products.index(recommended_product))
                update_interaction_state(query, excluded_indices)
                print("Recommendation accepted. Thank you!\n")
            elif feedback == 'q':
                print("Exiting program. Thank you!")
                return
            else:
                excluded_indices.append(products.index(recommended_product))
                update_interaction_state(query, excluded_indices)
                print("Let's try another recommendation...")

# Run the interactive recommendation
interactive_recommendation()
# Out:
# Please enter your query or press 'q' to quit: 3060
#
# Recommended Products:
# 1. Godrej Nav Tal 5 Lever Brass 3 Keys Blister Padlock 3060 (Model: 3060)
#
# Is Product 1 satisfactory? (True/False) or 'q' to quit: True
# Recommendation accepted. Thank you!
#
#
# Please enter your query or press 'q' to quit: table top basin
#
# Recommended Products:
# 1. Sulit Gold Table Top Designer Basin1216 (Model: TABLE TOP BASIN-GOLD)
# 2. Simpolo Artik-751 Handcrafted Table Top Basin (Model: HB-101)
# 3. Bell HM 0019 Porcelain Art Designer Table Top Basin (Model: HM 0019)
# 4. Bell HM 0039 Porcelain Art Designer Table Top Basin (Model: HM 0039)
# 5. Tita Pixal Table Top Basin (White) (Model: Basin-122)
#
# Is Product 1 satisfactory? (True/False) or 'q' to quit: True
# Recommendation accepted. Thank you!
#
#
# Is Product 2 satisfactory? (True/False) or 'q' to quit: True
# Recommendation accepted. Thank you!
#
#
# Is Product 3 satisfactory? (True/False) or 'q' to quit: True
# ...

# %%
# !pip install sentence_transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.1 MB/s eta 0:00:00
# ...

# %%
import re
import json
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# Function to save embeddings to a file
def save_embeddings(embeddings, filename):
    np.save(filename, embeddings)

# Function to load embeddings from a file
def load_embeddings(filename):
    return np.load(filename)

# Function to clean text by removing special characters and convert to lowercase
def clean_text(text):
    # Remove special characters, numbers, and extra spaces
    cleaned_text = re.sub(r'[^A-Za-z]', ' ', text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    return cleaned_text.strip().lower()

# Initialize the model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Load the dataset
try:
    with open('/content/converted_data.json', 'r') as file:
        products = json.load(file)

    # Add a 'feedback' key to each product and initialize it as an empty list
    for product in products:
        product['feedback'] = []

except FileNotFoundError:
    print("Error: Products data file ('/content/converted_data.json') not found.")
    exit()

# Try to load the state of previous interactions
try:
    with open('interaction_state.json', 'r') as file:
        interaction_state = json.load(file)
except FileNotFoundError:
    interaction_state = {}

# Try to load pre-computed embeddings or compute and save them
embedding_file = 'product_embeddings.npy'
try:
    encoded_descriptions = load_embeddings(embedding_file)
except FileNotFoundError:
    # Compute and save embeddings after cleaning and converting to lowercase
    descriptions = [clean_text(f"{product['model']} {product['title']}") for product in products]
    encoded_descriptions = model.encode(descriptions)
    save_embeddings(encoded_descriptions, embedding_file)

# Function to update the interaction state file
def update_interaction_state(query, excluded_indices):
    interaction_state[query] = excluded_indices
    with open('interaction_state.json', 'w') as file:
        json.dump(interaction_state, file)

# Function to recommend products based on a query with feedback loop
def recommend_products(query, num_recommendations=5, excluded_indices=[]):
    # Clean and convert the query to lowercase
    cleaned_query = clean_text(query)
    query_embedding = model.encode([cleaned_query])
    model_query = cleaned_query.split(' ')[0]  # Extract the model from the query

    # First, search for products with matching model
    model_match_indices = [i for i, product in enumerate(products) if product['model'] == model_query]

    if model_match_indices:
        model_match_indices = np.array(model_match_indices)
        similarities = cosine_similarity(query_embedding, encoded_descriptions[model_match_indices]).flatten()
        sorted_indices = model_match_indices[np.argsort(similarities)[::-1]]
    else:
        # If no matching models found, fallback to title-based recommendations
        similarities = cosine_similarity(query_embedding, encoded_descriptions).flatten()
        sorted_indices = np.argsort(similarities)[::-1]

    recommended_products = []
    for index in sorted_indices:
        if len(recommended_products) >= num_recommendations:
            break
        if index not in excluded_indices:
            recommended_products.append(products[index])

    return recommended_products

# Function to handle the interactive recommendation process
def interactive_recommendation():
    while True:
        query = input("\nPlease enter your query or press 'q' to quit: ").strip().lower()
        if query == 'q':
            print("Exiting program. Thank you!")
            break

        excluded_indices = interaction_state.get(query, [])
        recommended_products = recommend_products(query, num_recommendations=5, excluded_indices=excluded_indices)

        if not recommended_products:
            print(f"No recommendations found for the model: {query.split(' ')[0]}")
            continue

        # Show all 5 recommended products first
        print("\nRecommended Products:")
        for i, recommended_product in enumerate(recommended_products, start=1):
            print(f"{i}. {recommended_product['title']} (Model: {recommended_product['model']})")

        for i, recommended_product in enumerate(recommended_products, start=1):
            feedback = input(f"\nIs Product {i} satisfactory? (True/False) or 'q' to quit: ").strip().lower()

            if feedback == 'true':
                recommended_product['feedback'].append(True)  # Add 'True' to feedback list
                excluded_indices.append(products.index(recommended_product))
                update_interaction_state(query, excluded_indices)
                print("Recommendation accepted. Thank you!\n")
            elif feedback == 'q':
                print("Exiting program. Thank you!")
                return
            else:
                excluded_indices.append(products.index(recommended_product))
                update_interaction_state(query, excluded_indices)
                print("Let's try another recommendation...")

# Run the interactive recommendation
interactive_recommendation()
# Out:
# Please enter your query or press 'q' to quit: 3060
#
# Recommended Products:
# 1. Godrej Seethru Re 7 Lite Video Door Phone (Grey) (Model: )
# 2. Godrej Seethru 4.3 Lite Video Door Phone (Pearl) (Model: )
# 3. Godrej Premium Coffer V1 Red Home Locker (22L) (Model: )
# 4. Godrej Seethru Metal ST7 Lite Video Door Phone (White) (Model: )
# 5. Godrej Spotlight P.T Home Camera (White) (Model: )
#
# Is Product 1 satisfactory? (True/False) or 'q' to quit: 3060
# Let's try another recommendation...
#
# Is Product 2 satisfactory? (True/False) or 'q' to quit: q
# Exiting program. Thank you!
